# %%
import json
from nltk.corpus import stopwords

with open('data.json') as f:
    raw_json = json.load(f)

# %%
data = []
get_word_tokens = lambda words: [word.lower() for word in words if word.isalpha() and word.lower() not in stopwords.words('english')]
    
for index, i in enumerate(raw_json):
    qst_words = get_word_tokens(i['question'].split(' '))
    ans_words = get_word_tokens(i['answer'].split(' '))
    
    keywords = qst_words + ans_words
    
    data.append({
        'index': index,
        'question': i['question'],
        'answer': i['answer'],
        'keywords': keywords
    })

# %%
data[0]['keywords']
# Out:
# ['different',
#  'animals',
#  'perceive',
#  'different',
#  'colors',
#  'larger',
#  'animals',
#  'including',
#  'humans',
#  'special',
#  'cells',
#  'back',
#  'eyes',
#  'called',
#  'cone',
#  'cells',
#  'type',
#  'cone',
#  'cell',
#  'reacts',
#  'specific',
#  'wavelength',
#  'light',
#  'whose',
#  'color',
#  'corresponds',
#  'specific',
#  'part',
#  'rainbow',
#  'cell',
#  'hit',
#  'light',
#  'right',
#  'wavelength',
#  'sends',
#  'signal',
#  'brain',
#  'combines',
#  'information',
#  'cone',
#  'types',
#  'perceive',
#  'full',
#  'color',
#  'range',
#  'colors',
#  'animal',
#  'sees',
#  'depends',
#  'number',
#  'different',
#  'cone',
#  'types',
#  'wavelength',
#  'react',
#  'example',
#  'humans',
#  'three',
#  'cell',
#  'types',
#  'perceive',
#  'violet',
#  'green',
#  'yellow',
#  'us',
#  'lack',
#  'one',
#  'types',
#  'leading',
#  'green',
#  'red',
#  'color',
#  'blindness',
#  'species',
#  'bird',
#  'fish',
#  'hand',
#  'four',
#  'different',
#  'cell',
#  'types',
#  'giving',
#  'different',
#  'perception',
#  'colors']

# %%
# Inverted mapping of keywords to document files
inverted_json = {}

for index, item in enumerate(data):
    for keyword in item['keywords']:
        if keyword in inverted_json:
            inverted_json[keyword]['freq'] += 1
            inverted_json[keyword]['doc'].append(index)
        else:
            inverted_json[keyword] = {
                'freq': 1,
                'doc': [index]
            }

# Remove all duplicate values
for key, val in inverted_json.items():
    val['doc'] = list(set(val['doc']))

# %%
inverted_json
# Out:
# {'different': {'freq': 9, 'doc': [0, 4, 5]},
#  'animals': {'freq': 4, 'doc': [0, 8, 6]},
#  'perceive': {'freq': 3, 'doc': [0]},
#  'colors': {'freq': 3, 'doc': [0]},
#  'larger': {'freq': 3, 'doc': [0, 6]},
#  'including': {'freq': 1, 'doc': [0]},
#  'humans': {'freq': 5, 'doc': [0, 8, 7]},
#  'special': {'freq': 4, 'doc': [0, 8]},
#  'cells': {'freq': 3, 'doc': [0, 8]},
#  'back': {'freq': 1, 'doc': [0]},
#  'eyes': {'freq': 1, 'doc': [0]},
#  'called': {'freq': 3, 'doc': [0, 1, 4]},
#  'cone': {'freq': 4, 'doc': [0]},
#  'type': {'freq': 1, 'doc': [0]},
#  'cell': {'freq': 5, 'doc': [0, 7]},
#  'reacts': {'freq': 1, 'doc': [0]},
#  'specific': {'freq': 3, 'doc': [0, 4]},
#  'wavelength': {'freq': 3, 'doc': [0]},
#  'light': {'freq': 2, 'doc': [0]},
#  'whose': {'freq': 1, 'doc': [0]},
#  'color': {'freq': 4, 'doc': [0, 4]},
#  'corresponds': {'freq': 1, 'doc': [0]},
#  'part': {'freq': 2, 'doc': [0, 6]},
#  'rainbow': {'freq': 1, 'doc': [0]},
#  'hit': {'freq': 1, 'doc': [0]},
#  'right': {'freq': 2, 'doc': [0, 9]},
#  'sends': {'freq': 1, 'doc': [0]},
#  'signal': {'freq': 1, 'doc': [0]},
#  'brain': {'freq': 1, 'doc': [0]},
#  'combines': {'freq': 1, 'doc': [0]},
#  'information': {'freq': 1, 'doc': [0]},
#  'types': {'freq': 5, 'doc': [0]},
#  'full': {'freq': 1, 'doc': [0]},
#  'range': {'freq': 1, 'doc': [0]},
#  'animal': {'freq': 2, 'doc': [0, 8]},
#  'sees': {'freq': 1, 'doc': [0]},
#  'depends': {'freq': 1, 'doc': [0]},
#  'number': {'freq': 1, 'doc': [0]},
#  'react': {'freq': 1, 'doc': [0]},
#  'example': {'freq': 6, 'doc': [0, 9, 2, 6]},
#  'three': {'freq': 1, 'doc': [0]},
#  'violet': {'freq': 1, 'doc': [0]},
#  'green': {'freq': 2, 'doc': [0]},
#  'yellow': {'freq': 1, 'doc': [0]},
#  'us': {'freq': 1, 'doc': [0]},
#  'lack': {'freq': 1, 'doc': [0]},
#  'one': {'freq': 1, 'doc': [0]},
#  'leading': {'freq': 1, 'doc': [0]},
#  'red': {'freq': 1, 'doc': [0]},
#  'blindness': {'freq': 1, 'doc': [0]},
#  'species': {'freq': 2, 'doc': [0, 6]},
#  'bird': {'freq': 2, 'doc': [0, 6]},
#  'fish': {'freq': 1, 'doc': [0]},
#  'hand': {'freq': 2, 'doc': [0, 3]},
#  'four': {'freq': 1, 'doc': [0]},
#  'giving': {'freq': 1, 'doc': [0]},
#  'perception': {'freq': 1, 'doc': [0]},
#  'flutes': {'freq': 1, 'doc': [1]},
#  'classified': {'freq': 1, 'doc': [1]},
#  'woodwinds': {'freq': 4, 'doc': [1]},
#  'made': {'freq': 2, 'doc': [1]},
#  'metal': {'freq': 1, 'doc': [1]},
#  'contrary': {'freq': 1, 'doc': [1]},
#  'name': {'freq': 1, 'doc': [1]},
#  'suggests': {'freq': 1, 'doc': [1]},
#  'difference': {'freq': 2, 'doc': [1, 7]},
#  'brass': {'freq': 2, 'doc': [1]},
#  'instruments': {'freq': 2, 'doc': [1]},
#  'sound': {'freq': 3, 'doc': [1]},
#  'produced': {'freq': 2, 'doc': [1]},
#  'rather': {'freq': 1, 'doc': [1]},
#  'material': {'freq': 1, 'doc': [1]},
#  'large': {'freq': 3, 'doc': [1, 6]},
#  'amplify': {'freq': 1, 'doc': [1]},
#  'modify': {'freq': 1, 'doc': [1]},
#  'lips': {'freq': 1, 'doc': [1]},
#  'vibrating': {'freq': 3, 'doc': [1]},
#  'create': {'freq': 1, 'doc': [1]},
#  'wind': {'freq': 1, 'doc': [1]},
#  'directed': {'freq': 1, 'doc': [1]},
#  'happen': {'freq': 2, 'doc': [1, 2]},
#  'reed': {'freq': 1, 'doc': [1]},
#  'case': {'freq': 1, 'doc': [1]},
#  'oboes': {'freq': 1, 'doc': [1]},
#  'clarinets': {'freq': 1, 'doc': [1]},
#  'air': {'freq': 1, 'doc': [1]},
#  'column': {'freq': 1, 'doc': [1]},
#  'contained': {'freq': 1, 'doc': [1]},
#  'within': {'freq': 2, 'doc': [1, 4]},
#  'transverse': {'freq': 1, 'doc': [1]},
#  'flute': {'freq': 1, 'doc': [1]},
#  'recorder': {'freq': 1, 'doc': [1]},
#  'set': {'freq': 1, 'doc': [2]},
#  'date': {'freq': 2, 'doc': [2]},
#  'beginning': {'freq': 2, 'doc': [2]},
#  'end': {'freq': 3, 'doc': [2]},
#  'artistic': {'freq': 2, 'doc': [2]},
#  'period': {'freq': 5, 'doc': [2]},
#  'change': {'freq': 1, 'doc': [2]},
#  'gradually': {'freq': 1, 'doc': [2]},
#  'exact': {'freq': 1, 'doc': [2]},
#  'periods': {'freq': 1, 'doc': [2]},
#  'taught': {'freq': 1, 'doc': [2]},
#  'school': {'freq': 1, 'doc': [2]},
#  'mostly': {'freq': 2, 'doc': [2]},
#  'arbitrary': {'freq': 1, 'doc': [2]},
#  'art': {'freq': 2, 'doc': [2]},
#  'historians': {'freq': 1, 'doc': [2]},
#  'usually': {'freq': 1, 'doc': [2]},
#  'try': {'freq': 2, 'doc': [2, 6]},
#  'use': {'freq': 1, 'doc': [2]},
#  'major': {'freq': 1, 'doc': [2]},
#  'event': {'freq': 1, 'doc': [2]},
#  'creation': {'freq': 1, 'doc': [2]},
#  'piece': {'freq': 1, 'doc': [2]},
#  'features': {'freq': 2, 'doc': [2]},
#  'characteristics': {'freq': 1, 'doc': [2]},
#  'new': {'freq': 3, 'doc': [2, 6]},
#  'death': {'freq': 2, 'doc': [2]},
#  'representative': {'freq': 1, 'doc': [2]},
#  'character': {'freq': 1, 'doc': [2]},
#  'baroque': {'freq': 2, 'doc': [2]},
#  'widely': {'freq': 1, 'doc': [2]},
#  'thought': {'freq': 1, 'doc': [2]},
#  'start': {'freq': 1, 'doc': [2]},
#  'first': {'freq': 2, 'doc': [2]},
#  'representation': {'freq': 1, 'doc': [2]},
#  'opera': {'freq': 1, 'doc': [2]},
#  'famous': {'freq': 1, 'doc': [2]},
#  'composer': {'freq': 1, 'doc': [2]},
#  'johann': {'freq': 1, 'doc': [2]},
#  'sebastian': {'freq': 1, 'doc': [2]},
#  'bach': {'freq': 2, 'doc': [2]},
#  'however': {'freq': 2, 'doc': [8, 2]},
#  'musical': {'freq': 1, 'doc': [2]},
#  'styles': {'freq': 1, 'doc': [2]},
#  'actually': {'freq': 2, 'doc': [2, 6]},
#  'started': {'freq': 1, 'doc': [2]},
#  'changing': {'freq': 1, 'doc': [2]},
#  'long': {'freq': 1, 'doc': [2]},
#  'passed': {'freq': 1, 'doc': [2]},
#  'away': {'freq': 1, 'doc': [2]},
#  'already': {'freq': 1, 'doc': [2]},
#  'exhibiting': {'freq': 1, 'doc': [2]},
#  'become': {'freq': 1, 'doc': [2]},
#  'known': {'freq': 1, 'doc': [2]},
#  'classical': {'freq': 1, 'doc': [2]},
#  'general': {'freq': 1, 'doc': [2]},
#  'dates': {'freq': 1, 'doc': [2]},
#  'way': {'freq': 1, 'doc': [2]},
#  'remember': {'freq': 1, 'doc': [2]},
#  'came': {'freq': 1, 'doc': [2]},
#  'decades': {'freq': 1, 'doc': [2]},
#  'cover': {'freq': 1, 'doc': [2]},
#  'adults': {'freq': 1, 'doc': [3]},
#  'like': {'freq': 7, 'doc': [8, 3, 4, 5]},
#  'drinking': {'freq': 1, 'doc': [3]},
#  'coffee': {'freq': 2, 'doc': [3]},
#  'tastes': {'freq': 2, 'doc': [3, 4]},
#  'bad': {'freq': 1, 'doc': [3]},
#  'children': {'freq': 1, 'doc': [3]},
#  'generally': {'freq': 2, 'doc': [3]},
#  'sweet': {'freq': 1, 'doc': [3]},
#  'things': {'freq': 1, 'doc': [3]},
#  'probably': {'freq': 1, 'doc': [3]},
#  'growing': {'freq': 1, 'doc': [3]},
#  'sugars': {'freq': 1, 'doc': [3]},
#  'help': {'freq': 2, 'doc': [8, 3]},
#  'growth': {'freq': 1, 'doc': [3]},
#  'bitter': {'freq': 1, 'doc': [3]},
#  'acquired': {'freq': 1, 'doc': [3]},
#  'taste': {'freq': 5, 'doc': [3, 4]},
#  'happens': {'freq': 1, 'doc': [4]},
#  'wine': {'freq': 8, 'doc': [4]},
#  'ages': {'freq': 2, 'doc': [4]},
#  'make': {'freq': 4, 'doc': [9, 4]},
#  'better': {'freq': 4, 'doc': [4]},
#  'chemical': {'freq': 2, 'doc': [4]},
#  'reaction': {'freq': 2, 'doc': [4]},
#  'occurring': {'freq': 1, 'doc': [4]},
#  'changes': {'freq': 1, 'doc': [4]},
#  'flavor': {'freq': 2, 'doc': [9, 4]},
#  'also': {'freq': 2, 'doc': [4, 6]},
#  'affect': {'freq': 2, 'doc': [9, 4]},
#  'feels': {'freq': 1, 'doc': [4]},
#  'inside': {'freq': 2, 'doc': [9, 4]},
#  'mouth': {'freq': 1, 'doc': [4]},
#  'age': {'freq': 1, 'doc': [4]},
#  'though': {'freq': 1, 'doc': [4]},
#  'compound': {'freq': 1, 'doc': [4]},
#  'tannin': {'freq': 1, 'doc': [4]},
#  'big': {'freq': 1, 'doc': [4]},
#  'effect': {'freq': 1, 'doc': [4]},
#  'going': {'freq': 1, 'doc': [4]},
#  'aging': {'freq': 2, 'doc': [4]},
#  'wines': {'freq': 1, 'doc': [4]},
#  'amounts': {'freq': 1, 'doc': [4]},
#  'tannins': {'freq': 1, 'doc': [4]},
#  'equally': {'freq': 1, 'doc': [4]},
#  'exactly': {'freq': 1, 'doc': [5]},
#  'vitamins': {'freq': 3, 'doc': [5]},
#  'kind': {'freq': 1, 'doc': [5]},
#  'nutrition': {'freq': 2, 'doc': [8, 5]},
#  'body': {'freq': 1, 'doc': [5]},
#  'needs': {'freq': 3, 'doc': [8, 5, 7]},
#  'work': {'freq': 1, 'doc': [5]},
#  'properly': {'freq': 1, 'doc': [5]},
#  'need': {'freq': 2, 'doc': [5]},
#  'eat': {'freq': 2, 'doc': [8, 5]},
#  'variety': {'freq': 1, 'doc': [5]},
#  'foods': {'freq': 1, 'doc': [5]},
#  'bunch': {'freq': 1, 'doc': [5]},
#  'main': {'freq': 1, 'doc': [6]},
#  'predators': {'freq': 3, 'doc': [6]},
#  'zealand': {'freq': 2, 'doc': [6]},
#  'birds': {'freq': 6, 'doc': [6]},
#  'compared': {'freq': 1, 'doc': [6]},
#  'places': {'freq': 1, 'doc': [6]},
#  'world': {'freq': 1, 'doc': [6]},
#  'sure': {'freq': 1, 'doc': [6]},
#  'since': {'freq': 1, 'doc': [6]},
#  'island': {'freq': 2, 'doc': [6]},
#  'possible': {'freq': 1, 'doc': [6]},
#  'many': {'freq': 2, 'doc': [9, 6]},
#  'mammalian': {'freq': 1, 'doc': [6]},
#  'could': {'freq': 1, 'doc': [6]},
#  'access': {'freq': 2, 'doc': [8, 6]},
#  'mammals': {'freq': 2, 'doc': [6]},
#  'swim': {'freq': 1, 'doc': [6]},
#  'present': {'freq': 1, 'doc': [6]},
#  'seals': {'freq': 1, 'doc': [6]},
#  'whales': {'freq': 1, 'doc': [6]},
#  'time': {'freq': 3, 'doc': [9, 6]},
#  'ecological': {'freq': 1, 'doc': [6]},
#  'niche': {'freq': 1, 'doc': [6]},
#  'often': {'freq': 2, 'doc': [6]},
#  'occupy': {'freq': 1, 'doc': [6]},
#  'filled': {'freq': 1, 'doc': [6]},
#  'without': {'freq': 1, 'doc': [6]},
#  'traditional': {'freq': 1, 'doc': [6]},
#  'preyed': {'freq': 1, 'doc': [6]},
#  'population': {'freq': 1, 'doc': [6]},
#  'grew': {'freq': 1, 'doc': [6]},
#  'lot': {'freq': 4, 'doc': [8, 9, 6, 7]},
#  'flightless': {'freq': 1, 'doc': [6]},
#  'think': {'freq': 1, 'doc': [6]},
#  'prey': {'freq': 1, 'doc': [6]},
#  'getting': {'freq': 1, 'doc': [6]},
#  'moa': {'freq': 1, 'doc': [6]},
#  'ate': {'freq': 1, 'doc': [6]},
#  'got': {'freq': 1, 'doc': [6]},
#  'haast': {'freq': 1, 'doc': [6]},
#  'eagle': {'freq': 1, 'doc': [6]},
#  'viruses': {'freq': 2, 'doc': [7]},
#  'bacteria': {'freq': 4, 'doc': [7]},
#  'virus': {'freq': 1, 'doc': [7]},
#  'technically': {'freq': 1, 'doc': [7]},
#  'alive': {'freq': 1, 'doc': [7]},
#  'attach': {'freq': 1, 'doc': [7]},
#  'living': {'freq': 2, 'doc': [7]},
#  'host': {'freq': 1, 'doc': [7]},
#  'able': {'freq': 1, 'doc': [7]},
#  'reproduce': {'freq': 1, 'doc': [7]},
#  'organisms': {'freq': 1, 'doc': [7]},
#  'cause': {'freq': 1, 'doc': [7]},
#  'disease': {'freq': 1, 'doc': [7]},
#  'helpful': {'freq': 1, 'doc': [7]},
#  'well': {'freq': 1, 'doc': [7]},
#  'herbivore': {'freq': 1, 'doc': [8]},
#  'eats': {'freq': 2, 'doc': [8]},
#  'plants': {'freq': 4, 'doc': [8]},
#  'get': {'freq': 2, 'doc': [8]},
#  'protein': {'freq': 3, 'doc': [8]},
#  'survive': {'freq': 1, 'doc': [8]},
#  'grass': {'freq': 2, 'doc': [8]},
#  'herbivores': {'freq': 2, 'doc': [8]},
#  'unlike': {'freq': 1, 'doc': [8]},
#  'digestive': {'freq': 2, 'doc': [8]},
#  'systems': {'freq': 2, 'doc': [8]},
#  'let': {'freq': 1, 'doc': [8]},
#  'contain': {'freq': 1, 'doc': [8]},
#  'cellulose': {'freq': 3, 'doc': [8]},
#  'difficult': {'freq': 1, 'doc': [8]},
#  'digest': {'freq': 1, 'doc': [8]},
#  'cows': {'freq': 2, 'doc': [8]},
#  'process': {'freq': 1, 'doc': [8]},
#  'protected': {'freq': 1, 'doc': [8]},
#  'plant': {'freq': 1, 'doc': [8]},
#  'multiple': {'freq': 1, 'doc': [8]},
#  'stomachs': {'freq': 1, 'doc': [8]},
#  'areas': {'freq': 1, 'doc': [8]},
#  'stomach': {'freq': 1, 'doc': [8]},
#  'intestine': {'freq': 1, 'doc': [8]},
#  'digesting': {'freq': 1, 'doc': [8]},
#  'chocolate': {'freq': 5, 'doc': [9]},
#  'steps': {'freq': 1, 'doc': [9]},
#  'making': {'freq': 1, 'doc': [9]},
#  'cocoa': {'freq': 4, 'doc': [9]},
#  'tree': {'freq': 1, 'doc': [9]},
#  'harvested': {'freq': 1, 'doc': [9]},
#  'produce': {'freq': 1, 'doc': [9]},
#  'pods': {'freq': 2, 'doc': [9]},
#  'pulp': {'freq': 1, 'doc': [9]},
#  'fermented': {'freq': 1, 'doc': [9]},
#  'beans': {'freq': 3, 'doc': [9]},
#  'dried': {'freq': 1, 'doc': [9]},
#  'sun': {'freq': 1, 'doc': [9]},
#  'roasted': {'freq': 2, 'doc': [9]},
#  'step': {'freq': 1, 'doc': [9]},
#  'variability': {'freq': 1, 'doc': [9]},
#  'temperature': {'freq': 1, 'doc': [9]},
#  'roast': {'freq': 1, 'doc': [9]},
#  'processed': {'freq': 1, 'doc': [9]},
#  'remove': {'freq': 1, 'doc': [9]},
#  'shell': {'freq': 1, 'doc': [9]},
#  'nibs': {'freq': 1, 'doc': [9]},
#  'ground': {'freq': 1, 'doc': [9]},
#  'tempered': {'freq': 1, 'doc': [9]},
#  'form': {'freq': 1, 'doc': [9]},
#  'texture': {'freq': 1, 'doc': [9]},
#  'finally': {'freq': 1, 'doc': [9]},
#  'molded': {'freq': 1, 'doc': [9]},
#  'bar': {'freq': 1, 'doc': [9]}}

# %%
inverted_json_keys = list(inverted_json.keys())

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.children = {}
        self.end = False
        self.suggestion_list = []
        self.base = ''
        
class Trie:
    def __init__(self):
        self.root = TreeNode('')
        
    def insert(self, word):
        root = self.root
        for index, letter in enumerate(word):
            if letter not in root.children:
                root.children[letter] = TreeNode(letter)
            root = root.children[letter]
        if index == len(word)-1: root.end = True

# %%
# All keywords formed in a trie ds
trie_root_node = Trie()

for word in inverted_json_keys:
    trie_root_node.insert(word)
    
prefix_hash_table = {}

# Organising the Tries
def dfs(root, curr_word=''):
    root.base = curr_word
    prefix_hash_table[root.base] = root.suggestion_list
    if root.end: 
        root.suggestion_list.append(curr_word)
        return [curr_word]
    
    for val, node in root.children.items():
        to_return = dfs(node, curr_word+node.val)
        root.suggestion_list += to_return
    
    return root.suggestion_list
        
dfs(trie_root_node.root)

# Remove the null entry
prefix_hash_table.pop('', None)
# Out:
# ['camel',
#  'cameron',
#  'car',
#  'cast',
#  'cold',
#  'common',
#  'camel',
#  'cameron',
#  'car',
#  'cast',
#  'cold',
#  'common',
#  'camel',
#  'cameron',
#  'car',
#  'cast',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'car',
#  'cast',
#  'cast',
#  'cold',
#  'common',
#  'cold',
#  'cold',
#  'common',
#  'common',
#  'common',
#  'common',
#  'camel',
#  'cameron',
#  'car',
#  'cast',
#  'cold',
#  'common',
#  'camel',
#  'cameron',
#  'car',
#  'cast',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'car',
#  'cast',
#  'cast',
#  'cold',
#  'common',
#  'cold',
#  'cold',
#  'common',
#  'common',
#  'common',
#  'common',
#  'camel',
#  'cameron',
#  'car',
#  'cast',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'car',
#  'cast',
#  'cast',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'camel',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'camel',
#  'cameron',
#  'cameron',
#  'cameron',
#  'cameron',
#  'cameron',
#  'cameron',
#  'car',
#  'cast',
#  'cast',
#  'cast',
#  'cold',
#  'common',
#  'cold',
#  'cold',
#  'common',
#  'common',
#  'common',
#  'common',
#  'cold',
#  'cold',
#  'cold',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common']

# %%
# DFS on tries to get the words

q = [trie_root_node_test.root]
# v = [trie_root_node]
curr_word = ''

while q:
    root = q.pop()
    print(root.val)
    curr_word += root.val
    if root.end:
#         root.suggestion_list.append(curr_word)
        print(curr_word)
#         curr_word = curr_word[:-1]
    for val, node in root.children.items():
        q.append(node)
# Out:
# c
# o
# m
# m
# o
# n
# common
# l
# d
# commonld
# a
# s
# t
# commonldast
# r
# commonldastr
# m
# e
# r
# o
# n
# commonldastrmeron
# l
# commonldastrmeronl

# %%
# All keywords formed in a trie
trie_root_node_test = Trie()

test_words = ['camel', 'car', 'cast', 'cameron', 'cold', 'common']

for word in test_words:
    trie_root_node_test.insert(word)
    
prefix_hash_table = {}

# Organising the Tries
def dfs(root, curr_word=''):
    root.base = curr_word
    prefix_hash_table[root.base] = root.suggestion_list
    if root.end: 
        root.suggestion_list.append(curr_word)
        return [curr_word]
    
    for val, node in root.children.items():
        to_return = dfs(node, curr_word+node.val)
        root.suggestion_list += to_return
    
    return root.suggestion_list
        
dfs(trie_root_node_test.root)

# Remove the null entry
prefix_hash_table.pop('', None)
# Out:
# ['camel', 'cameron', 'car', 'cast', 'cold', 'common']

# %%
# View All suggestion list
def dfs(root, curr_word=''):
    print(f'root: {root.val}, base: {root.base}, suggestion_list: {root.suggestion_list}')
    for val, node in root.children.items():
        dfs(node, curr_word)
        
dfs(trie_root_node_test.root)
# Out:
# root: , base: , suggestion_list: ['camel', 'cameron', 'car', 'cast', 'cold', 'common']
# root: c, base: c, suggestion_list: ['camel', 'cameron', 'car', 'cast', 'cold', 'common']
# root: a, base: ca, suggestion_list: ['camel', 'cameron', 'car', 'cast']
# root: m, base: cam, suggestion_list: ['camel', 'cameron']
# root: e, base: came, suggestion_list: ['camel', 'cameron']
# root: l, base: camel, suggestion_list: ['camel']
# root: r, base: camer, suggestion_list: ['cameron']
# root: o, base: camero, suggestion_list: ['cameron']
# root: n, base: cameron, suggestion_list: ['cameron']
# root: r, base: car, suggestion_list: ['car']
# root: s, base: cas, suggestion_list: ['cast']
# root: t, base: cast, suggestion_list: ['cast']
# root: o, base: co, suggestion_list: ['cold', 'common']
# root: l, base: col, suggestion_list: ['cold']
# root: d, base: cold, suggestion_list: ['cold']
# root: m, base: com, suggestion_list: ['common']
# root: m, base: comm, suggestion_list: ['common']
# root: o, base: commo, suggestion_list: ['common']
# root: n, base: common, suggestion_list: ['common']

# %%
inverted_json.items()
# Out:
# dict_items([('different', {'freq': 9, 'doc': [0, 4, 5]}), ('animals', {'freq': 4, 'doc': [0, 8, 6]}), ('perceive', {'freq': 3, 'doc': [0]}), ('colors', {'freq': 3, 'doc': [0]}), ('larger', {'freq': 3, 'doc': [0, 6]}), ('including', {'freq': 1, 'doc': [0]}), ('humans', {'freq': 5, 'doc': [0, 8, 7]}), ('special', {'freq': 4, 'doc': [0, 8]}), ('cells', {'freq': 3, 'doc': [0, 8]}), ('back', {'freq': 1, 'doc': [0]}), ('eyes', {'freq': 1, 'doc': [0]}), ('called', {'freq': 3, 'doc': [0, 1, 4]}), ('cone', {'freq': 4, 'doc': [0]}), ('type', {'freq': 1, 'doc': [0]}), ('cell', {'freq': 5, 'doc': [0, 7]}), ('reacts', {'freq': 1, 'doc': [0]}), ('specific', {'freq': 3, 'doc': [0, 4]}), ('wavelength', {'freq': 3, 'doc': [0]}), ('light', {'freq': 2, 'doc': [0]}), ('whose', {'freq': 1, 'doc': [0]}), ('color', {'freq': 4, 'doc': [0, 4]}), ('corresponds', {'freq': 1, 'doc': [0]}), ('part', {'freq': 2, 'doc': [0, 6]}), ('rainbow', {'freq': 1, 'doc': [0]}), ('hit', {'freq': 1, 'doc': [0]}), ('right', {'freq': 2, 'doc': [0, 9]}), ('sends', {'freq': 1, 'doc': [0]}), ('signal', {'freq': 1, 'doc': [0]}), ('brain', {'freq': 1, 'doc': [0]}), ('combines', {'freq': 1, 'doc': [0]}), ('information', {'freq': 1, 'doc': [0]}), ('types', {'freq': 5, 'doc': [0]}), ('full', {'freq': 1, 'doc': [0]}), ('range', {'freq': 1, 'doc': [0]}), ('animal', {'freq': 2, 'doc': [0, 8]}), ('sees', {'freq': 1, 'doc': [0]}), ('depends', {'freq': 1, 'doc': [0]}), ('number', {'freq': 1, 'doc': [0]}), ('react', {'freq': 1, 'doc': [0]}), ('example', {'freq': 6, 'doc': [0, 9, 2, 6]}), ('three', {'freq': 1, 'doc': [0]}), ('violet', {'freq': 1, 'doc': [0]}), ('green', {'freq': 2, 'doc': [0]}), ('yellow', {'freq': 1, 'doc': [0]}), ('us', {'freq': 1, 'doc': [0]}), ('lack', {'freq': 1, 'doc': [0]}), ('one', {'freq': 1, 'doc': [0]}), ('leading', {'freq': 1, 'doc': [0]}), ('red', {'freq': 1, 'doc': [0]}), ('blindness', {'freq': 1, 'doc': [0]}), ('species', {'freq': 2, 'doc': [0, 6]}), ('bird', {'freq': 2, 'doc': [0, 6]}), ('fish', {'freq': 1, 'doc': [0]}), ('hand', {'freq': 2, 'doc': [0, 3]}), ('four', {'freq': 1, 'doc': [0]}), ('giving', {'freq': 1, 'doc': [0]}), ('perception', {'freq': 1, 'doc': [0]}), ('flutes', {'freq': 1, 'doc': [1]}), ('classified', {'freq': 1, 'doc': [1]}), ('woodwinds', {'freq': 4, 'doc': [1]}), ('made', {'freq': 2, 'doc': [1]}), ('metal', {'freq': 1, 'doc': [1]}), ('contrary', {'freq': 1, 'doc': [1]}), ('name', {'freq': 1, 'doc': [1]}), ('suggests', {'freq': 1, 'doc': [1]}), ('difference', {'freq': 2, 'doc': [1, 7]}), ('brass', {'freq': 2, 'doc': [1]}), ('instruments', {'freq': 2, 'doc': [1]}), ('sound', {'freq': 3, 'doc': [1]}), ('produced', {'freq': 2, 'doc': [1]}), ('rather', {'freq': 1, 'doc': [1]}), ('material', {'freq': 1, 'doc': [1]}), ('large', {'freq': 3, 'doc': [1, 6]}), ('amplify', {'freq': 1, 'doc': [1]}), ('modify', {'freq': 1, 'doc': [1]}), ('lips', {'freq': 1, 'doc': [1]}), ('vibrating', {'freq': 3, 'doc': [1]}), ('create', {'freq': 1, 'doc': [1]}), ('wind', {'freq': 1, 'doc': [1]}), ('directed', {'freq': 1, 'doc': [1]}), ('happen', {'freq': 2, 'doc': [1, 2]}), ('reed', {'freq': 1, 'doc': [1]}), ('case', {'freq': 1, 'doc': [1]}), ('oboes', {'freq': 1, 'doc': [1]}), ('clarinets', {'freq': 1, 'doc': [1]}), ('air', {'freq': 1, 'doc': [1]}), ('column', {'freq': 1, 'doc': [1]}), ('contained', {'freq': 1, 'doc': [1]}), ('within', {'freq': 2, 'doc': [1, 4]}), ('transverse', {'freq': 1, 'doc': [1]}), ('flute', {'freq': 1, 'doc': [1]}), ('recorder', {'freq': 1, 'doc': [1]}), ('set', {'freq': 1, 'doc': [2]}), ('date', {'freq': 2, 'doc': [2]}), ('beginning', {'freq': 2, 'doc': [2]}), ('end', {'freq': 3, 'doc': [2]}), ('artistic', {'freq': 2, 'doc': [2]}), ('period', {'freq': 5, 'doc': [2]}), ('change', {'freq': 1, 'doc': [2]}), ('gradually', {'freq': 1, 'doc': [2]}), ('exact', {'freq': 1, 'doc': [2]}), ('periods', {'freq': 1, 'doc': [2]}), ('taught', {'freq': 1, 'doc': [2]}), ('school', {'freq': 1, 'doc': [2]}), ('mostly', {'freq': 2, 'doc': [2]}), ('arbitrary' ...

# %%
prefix_hash_table
# Out:
# {'c': ['camel', 'cameron', 'car', 'cast', 'cold', 'common'],
#  'ca': ['camel', 'cameron', 'car', 'cast'],
#  'cam': ['camel', 'cameron'],
#  'came': ['camel', 'cameron'],
#  'camel': ['camel'],
#  'camer': ['cameron'],
#  'camero': ['cameron'],
#  'cameron': ['cameron'],
#  'car': ['car'],
#  'cas': ['cast'],
#  'cast': ['cast'],
#  'co': ['cold', 'common'],
#  'col': ['cold'],
#  'cold': ['cold'],
#  'com': ['common'],
#  'comm': ['common'],
#  'commo': ['common'],
#  'common': ['common']}

# %%
with open('testing.js', 'w') as w:
    w.write('data = ')
    json.dump(prefix_hash_table, w)
