# %%
import json
from nltk.corpus import stopwords

with open('data.json') as f:
    raw_json = json.load(f)

# %%
data = []
get_word_tokens = lambda words: [word.lower() for word in words if word.isalpha() and word.lower() not in stopwords.words('english')]
    
for index, i in enumerate(raw_json):
    qst_words = get_word_tokens(i['question'].split(' '))
    ans_words = get_word_tokens(i['answer'].split(' '))
    
    keywords = qst_words + ans_words
    
    data.append({
        'index': index,
        'question': i['question'],
        'answer': i['answer'],
        'keywords': keywords
    })

# %%
data
# Out:
# [{'index': 0,
#   'question': 'How can different animals perceive different colors ? --T-- ',
#   'answer': 'Larger animals ( including humans ) have special cells in the back of their eyes called cone cells . Each type of cone cell reacts to a specific wavelength : that is , light whose color corresponds to a specific part of the rainbow . When the cell is hit by light with the right wavelength , it sends a signal to the brain , which combines information from all of the cone types to perceive the full color range . What colors each animal sees depends on the number of different cone types , and what wavelength they react to . For example , most humans have three cell types which perceive violet , green , and yellow , but some of us lack one of these types , leading to green - red color - blindness . Some species of bird or fish on the other hand have four different cell types , giving them a very different perception of colors .',
#   'keywords': ['different',
#    'animals',
#    'perceive',
#    'different',
#    'colors',
#    'larger',
#    'animals',
#    'including',
#    'humans',
#    'special',
#    'cells',
#    'back',
#    'eyes',
#    'called',
#    'cone',
#    'cells',
#    'type',
#    'cone',
#    'cell',
#    'reacts',
#    'specific',
#    'wavelength',
#    'light',
#    'whose',
#    'color',
#    'corresponds',
#    'specific',
#    'part',
#    'rainbow',
#    'cell',
#    'hit',
#    'light',
#    'right',
#    'wavelength',
#    'sends',
#    'signal',
#    'brain',
#    'combines',
#    'information',
#    'cone',
#    'types',
#    'perceive',
#    'full',
#    'color',
#    'range',
#    'colors',
#    'animal',
#    'sees',
#    'depends',
#    'number',
#    'different',
#    'cone',
#    'types',
#    'wavelength',
#    'react',
#    'example',
#    'humans',
#    'three',
#    'cell',
#    'types',
#    'perceive',
#    'violet',
#    'green',
#    'yellow',
#    'us',
#    'lack',
#    'one',
#    'types',
#    'leading',
#    'green',
#    'red',
#    'color',
#    'blindness',
#    'species',
#    'bird',
#    'fish',
#    'hand',
#    'four',
#    'different',
#    'cell',
#    'types',
#    'giving',
#    'different',
#    'perception',
#    'colors']},
#  {'index': 1,
#   'question': 'Why are flutes classified as woodwinds when most of them are made out of metal ? --T-- ',
#   'answer': 'Contrary to what the name suggests , the difference between woodwinds and brass instruments is about how the sound is produced rather than what material they are made of . By and large , brass instruments amplify or modify the sound produced by lips vibrating against each other , while woodwinds create their own sound when wind is directed through them . This can happen by vibrating a reed in the case of oboes or clarinets , or by vibrating the air column contained within a transverse flute or a recorder , which is why they are called woodwinds .',
#   'keywords': ['flutes',
#    'classified',
#    'woodwinds',
#    'made',
#    'metal',
#    'contrary',
#    'name',
#    'suggests',
#    'difference',
#    'woodwinds',
#    'brass',
#    'instruments',
#    'sound',
#    'produced',
#    'rather',
#    'material',
#    'made',
#    'large',
#    'brass',
#    'instruments',
#    'amplify',
#    'modify',
#    'sound',
#    'produced',
#    'lips',
#    'vibrating',
#    'woodwinds',
#    'create',
#    'sound',
#    'wind',
#    'directed',
#    'happen',
#    'vibrating',
#    'reed',
#    'case',
#    'oboes',
#    'clarinets',
#    'vibrating',
#    'air',
#    'column',
#    'contained',
#    'within',
#    'transverse',
#    'flute',
#    'recorder',
#    'called',
#    'woodwinds']},
#  {'index': 2,
#   'question': "How can we set a date to the beginning or end of an artistic period ? Does n't the change happen gradually ? --T-- ",
#   'answer': "The exact beginning or end date of artistic periods that are taught in school are mostly arbitrary . Art historians usually try to use a major event or the creation of an art piece that features characteristics of the new period , or the death of a representative character . For example , the Baroque period is widely thought to start with the first representation of the first Baroque opera , l'Orfeo , in 1607 , and end with the death of its most famous composer , Johann Sebastian Bach , in 1750 . However , musical styles had actually started changing long before Bach passed away , and were already exhibiting features of what was to become known as the Classical period . In general these dates are mostly just a way to remember which period came after which and what decades they cover .",
#   'keywords': ['set',
#    'date',
#    'beginning',
#    'end',
#    'artistic',
#    'period',
#    'change',
#    'happen',
#    'gradually',
#    'exact',
#    'beginning',
#    'end',
#    'date',
#    'artistic',
#    'periods',
#    'taught',
#    'school',
#    'mostly',
#    'arbitrary',
#    'art',
#    'historians',
#    'usually',
#    'try',
#    'use',
#    'major',
#    'event',
#    'creation',
#    'art',
#    'piece',
#    'features',
#    'characteristics',
#    'new',
#    'period',
#    'death',
#    'representative',
#    'character',
#    'example',
#    'baroque',
#    'period',
#    'widely',
#    'thought',
#    'start',
#    'first',
#    'representation',
#    'first',
#    'baroque',
#    'opera',
#    'end',
#    'death',
#    'famous',
#    'composer',
#    'johann',
#    'sebastian',
#    'bach',
#    'however',
#    'musical',
#    'styles',
#    'actually',
#    'started',
#    'changing',
#    'long',
#    'bach',
#    'passed',
#    'away',
#    'already',
#    'exhibiting',
#    'features',
#    'become',
#    'known',
#    'classical',
#    'period',
#    'general',
#    'dates',
#    'mostly',
#    'way',
#    'remember',
#    'period',
#    'came',
#    'decades',
#    'cover']},
#  {'index': 3,
#   'question': 'Why do adults like drinking coffee when it tastes so bad ? --T-- ',
#   'answer': 'Children generally like sweet things , probably because they are growing and sugars help with that growth . Coffee , on the other hand , is bitter and generally an acquired taste .',
#   'keywords': ['adults',
#    'like',
#    'drinking',
#    'coffee',
#    'tastes',
#    'bad',
#    'children',
#    'generally',
#    'like',
#    'sweet',
#    'things',
#    'probably',
#    'growing',
#    'sugars',
#    'help',
#    'growth',
#    'coffee',
#    'hand',
#    'bitter',
#    'generally',
#    'acquired',
#    'taste']},
#  {'index': 4,
#   'question': 'What happens when wine ages ? How does it make the wine taste better ? --T-- ',
#   'answer': 'When wine ages , a chemical reaction is occurring within the wine . This chemical reaction changes the flavor to make it taste better , and can also affect the color and how it feels inside your mouth . Not all wine tastes better with age , though . There is a specific compound in wine called tannin that has a big effect on what the wine is going to taste like after aging . Different wines have different amounts of these tannins , so not all wine will taste equally better after aging .',
#   'keywords': ['happens',
#    'wine',
#    'ages',
#    'make',
#    'wine',
#    'taste',
#    'better',
#    'wine',
#    'ages',
#    'chemical',
#    'reaction',
#    'occurring',
#    'within',
#    'wine',
#    'chemical',
#    'reaction',
#    'changes',
#    'flavor',
#    'make',
#    'taste',
#    'better',
#    'also',
#    'affect',
#    'color',
#    'feels',
#    'inside',
#    'mouth',
#    'wine',
#    'tastes',
#    'better',
#    'age',
#    'though',
#    'specific',
#    'compound',
#    'wine',
#    'called',
#    'tannin',
#    'big',
#    'effect',
#    'wine',
#    'going',
#    'taste',
#    'like',
#    'aging',
#    'different',
#    'wines',
#    'different',
#    'amounts',
#    'tannins',
#    'wine',
#    'taste',
#    'equally',
#    'better',
#    'aging']},
#  {'index': 5,
#   'question': 'What exactly are vitamins ? --T-- ',
#   'answer': 'Vitamins are a kind of nutrition that your body needs to work properly . Just like you need to eat a variety of different foods , you need a bunch of different vitamins .',
#   'keywords': ['exactly',
#    'vitamins',
#    'vitamins',
#    'kind',
#    'nutrition',
#    'body',
#    'needs',
#    'work',
#    'properly',
#    'like',
#    'need',
#    'eat',
#    'variety',
#    'different',
#    'foods',
#    'need',
#    'bunch',
#    'different',
#    'vitamins']},
#  {'index': 6,
#   'question': 'Why were the main predators in New Zealand large birds , compared to other places in the world ? --T-- ',
#   'answer': "I 'm not 100 % sure about this , but I 'll try . Since New Zealand is an island , it 's possible that many mammalian species could not access it . There are mammals that can swim to the island that are present , for example seals or whales . Over time , the ecological niche that mammals often occupy were filled by birds . Without traditional predators that often preyed on birds , the bird population grew and actually a lot of these birds were flightless . For the part about large birds --- I think because birds that were prey animals were getting larger , for example the Moa , the predators that ate them also got larger over time , for example the Haast eagle .",
#   'keywords': ['main',
#    'predators',
#    'new',
#    'zealand',
#    'large',
#    'birds',
#    'compared',
#    'places',
#    'world',
#    'sure',
#    'try',
#    'since',
#    'new',
#    'zealand',
#    'island',
#    'possible',
#    'many',
#    'mammalian',
#    'species',
#    'could',
#    'access',
#    'mammals',
#    'swim',
#    'island',
#    'present',
#    'example',
#    'seals',
#    'whales',
#    'time',
#    'ecological',
#    'niche',
#    'mammals',
#    'often',
#    'occupy',
#    'filled',
#    'birds',
#    'without',
#    'traditional',
#    'predators',
#    'often',
#    'preyed',
#    'birds',
#    'bird',
#    'population',
#    'grew',
#    'actually',
#    'lot',
#    'birds',
#    'flightless',
#    'part',
#    'large',
#    'birds',
#    'think',
#    'birds',
#    'prey',
#    'animals',
#    'getting',
#    'larger',
#    'example',
#    'moa',
#    'predators',
#    'ate',
#    'also',
#    'got',
#    'larger',
#    'time',
#    'example',
#    'haast',
#    'eagle']},
#  {'index': 7,
#   'question': "What 's the difference between viruses and bacteria ? --T-- ",
#   'answer': 'A virus is not technically alive , because it needs to attach itself to a living host cell to be able to reproduce . Bacteria are living organisms . Both viruses and bacteria can cause disease , but there are a lot of bacteria that are helpful to humans as well .',
#   'keywords': ['difference',
#    'viruses',
#    'bacteria',
#    'virus',
#    'technically',
#    'alive',
#    'needs',
#    'attach',
#    'living',
#    'host',
#    'cell',
#    'able',
#    'reproduce',
#    'bacteria',
#    'living',
#    'organisms',
#    'viruses',
#    'bacteria',
#    'cause',
#    'disease',
#    'lot',
#    'bacteria',
#    'helpful',
#    'humans',
#    'well']},
#  {'index': 8,
#   'question': 'If an animal is an herbivore ( only eats plants ) , where does it get the protein that it needs to survive if it only eats grass ? --T-- ',
#   'answer': 'Herbivores only eat plants , but unlike humans they have special digestive systems that let them get protein from grass . Plants contain cellulose , which is difficult for humans to digest . However , animals like cows have special digestive systems that can process the cellulose and then access nutrition like protein that are protected by the cellulose in plant cells . A lot of herbivores have multiple stomachs ( like cows ) or special areas in the stomach or intestine that can help in digesting plants .',
#   'keywords': ['animal',
#    'herbivore',
#    'eats',
#    'plants',
#    'get',
#    'protein',
#    'needs',
#    'survive',
#    'eats',
#    'grass',
#    'herbivores',
#    'eat',
#    'plants',
#    'unlike',
#    'humans',
#    'special',
#    'digestive',
#    'systems',
#    'let',
#    'get',
#    'protein',
#    'grass',
#    'plants',
#    'contain',
#    'cellulose',
#    'difficult',
#    'humans',
#    'digest',
#    'however',
#    'animals',
#    'like',
#    'cows',
#    'special',
#    'digestive',
#    'systems',
#    'process',
#    'cellulose',
#    'access',
#    'nutrition',
#    'like',
#    'protein',
#    'protected',
#    'cellulose',
#    'plant',
#    'cells',
#    'lot',
#    'herbivores',
#    'multiple',
#    'stomachs',
#    'like',
#    'cows',
#    'special',
#    'areas',
#    'stomach',
#    'intestine',
#    'help',
#    'digesting',
#    'plants']},
#  {'index': 9,
#   'question': 'How do you make chocolate ? --T-- ',
#   'answer': 'There are many steps in making chocolate . 1 . The cocoa tree is harvested to produce cocoa pods . 2 . The pods and the pulp inside them is fermented . 3 . The beans are dried in the sun . 4 . The beans are roasted . This step has a lot of variability , and the temperature and roast time will affect the flavor of the chocolate . 5 . The roasted cocoa beans have to be processed to remove the shell . 6 . The cocoa nibs are ground up and then tempered to form the right texture . 7 . Finally , the chocolate is molded , for example to make a chocolate bar .',
#   'keywords': ['make',
#    'chocolate',
#    'many',
#    'steps',
#    'making',
#    'chocolate',
#    'cocoa',
#    'tree',
#    'harvested',
#    'produce',
#    'cocoa',
#    'pods',
#    'pods',
#    'pulp',
#    'inside',
#    'fermented',
#    'beans',
#    'dried',
#    'sun',
#    'beans',
#    'roasted',
#    'step',
#    'lot',
#    'variability',
#    'temperature',
#    'roast',
#    'time',
#    'affect',
#    'flavor',
#    'chocolate',
#    'roasted',
#    'cocoa',
#    'beans',
#    'processed',
#    'remove',
#    'shell',
#    'cocoa',
#    'nibs',
#    'ground',
#    'tempered',
#    'form',
#    'right',
#    'texture',
#    'finally',
#    'chocolate',
#    'molded',
#    'example',
#    'make',
#    'chocolate',
#    'bar']}]

# %%
# Inverted mapping of keywords to document files
inverted_json = {}

for index, item in enumerate(data):
    for keyword in item['keywords']:
        if keyword in inverted_json:
            inverted_json[keyword]['freq'] += 1
            inverted_json[keyword]['doc'].append(index)
        else:
            inverted_json[keyword] = {
                'freq': 1,
                'doc': [index]
            }

# Remove all duplicate values
for key, val in inverted_json.items():
    val['doc'] = list(set(val['doc']))

# %%
inverted_json
# Out:
# {'different': {'freq': 9, 'doc': [0, 4, 5]},
#  'animals': {'freq': 4, 'doc': [0, 8, 6]},
#  'perceive': {'freq': 3, 'doc': [0]},
#  'colors': {'freq': 3, 'doc': [0]},
#  'larger': {'freq': 3, 'doc': [0, 6]},
#  'including': {'freq': 1, 'doc': [0]},
#  'humans': {'freq': 5, 'doc': [0, 8, 7]},
#  'special': {'freq': 4, 'doc': [0, 8]},
#  'cells': {'freq': 3, 'doc': [0, 8]},
#  'back': {'freq': 1, 'doc': [0]},
#  'eyes': {'freq': 1, 'doc': [0]},
#  'called': {'freq': 3, 'doc': [0, 1, 4]},
#  'cone': {'freq': 4, 'doc': [0]},
#  'type': {'freq': 1, 'doc': [0]},
#  'cell': {'freq': 5, 'doc': [0, 7]},
#  'reacts': {'freq': 1, 'doc': [0]},
#  'specific': {'freq': 3, 'doc': [0, 4]},
#  'wavelength': {'freq': 3, 'doc': [0]},
#  'light': {'freq': 2, 'doc': [0]},
#  'whose': {'freq': 1, 'doc': [0]},
#  'color': {'freq': 4, 'doc': [0, 4]},
#  'corresponds': {'freq': 1, 'doc': [0]},
#  'part': {'freq': 2, 'doc': [0, 6]},
#  'rainbow': {'freq': 1, 'doc': [0]},
#  'hit': {'freq': 1, 'doc': [0]},
#  'right': {'freq': 2, 'doc': [0, 9]},
#  'sends': {'freq': 1, 'doc': [0]},
#  'signal': {'freq': 1, 'doc': [0]},
#  'brain': {'freq': 1, 'doc': [0]},
#  'combines': {'freq': 1, 'doc': [0]},
#  'information': {'freq': 1, 'doc': [0]},
#  'types': {'freq': 5, 'doc': [0]},
#  'full': {'freq': 1, 'doc': [0]},
#  'range': {'freq': 1, 'doc': [0]},
#  'animal': {'freq': 2, 'doc': [0, 8]},
#  'sees': {'freq': 1, 'doc': [0]},
#  'depends': {'freq': 1, 'doc': [0]},
#  'number': {'freq': 1, 'doc': [0]},
#  'react': {'freq': 1, 'doc': [0]},
#  'example': {'freq': 6, 'doc': [0, 9, 2, 6]},
#  'three': {'freq': 1, 'doc': [0]},
#  'violet': {'freq': 1, 'doc': [0]},
#  'green': {'freq': 2, 'doc': [0]},
#  'yellow': {'freq': 1, 'doc': [0]},
#  'us': {'freq': 1, 'doc': [0]},
#  'lack': {'freq': 1, 'doc': [0]},
#  'one': {'freq': 1, 'doc': [0]},
#  'leading': {'freq': 1, 'doc': [0]},
#  'red': {'freq': 1, 'doc': [0]},
#  'blindness': {'freq': 1, 'doc': [0]},
#  'species': {'freq': 2, 'doc': [0, 6]},
#  'bird': {'freq': 2, 'doc': [0, 6]},
#  'fish': {'freq': 1, 'doc': [0]},
#  'hand': {'freq': 2, 'doc': [0, 3]},
#  'four': {'freq': 1, 'doc': [0]},
#  'giving': {'freq': 1, 'doc': [0]},
#  'perception': {'freq': 1, 'doc': [0]},
#  'flutes': {'freq': 1, 'doc': [1]},
#  'classified': {'freq': 1, 'doc': [1]},
#  'woodwinds': {'freq': 4, 'doc': [1]},
#  'made': {'freq': 2, 'doc': [1]},
#  'metal': {'freq': 1, 'doc': [1]},
#  'contrary': {'freq': 1, 'doc': [1]},
#  'name': {'freq': 1, 'doc': [1]},
#  'suggests': {'freq': 1, 'doc': [1]},
#  'difference': {'freq': 2, 'doc': [1, 7]},
#  'brass': {'freq': 2, 'doc': [1]},
#  'instruments': {'freq': 2, 'doc': [1]},
#  'sound': {'freq': 3, 'doc': [1]},
#  'produced': {'freq': 2, 'doc': [1]},
#  'rather': {'freq': 1, 'doc': [1]},
#  'material': {'freq': 1, 'doc': [1]},
#  'large': {'freq': 3, 'doc': [1, 6]},
#  'amplify': {'freq': 1, 'doc': [1]},
#  'modify': {'freq': 1, 'doc': [1]},
#  'lips': {'freq': 1, 'doc': [1]},
#  'vibrating': {'freq': 3, 'doc': [1]},
#  'create': {'freq': 1, 'doc': [1]},
#  'wind': {'freq': 1, 'doc': [1]},
#  'directed': {'freq': 1, 'doc': [1]},
#  'happen': {'freq': 2, 'doc': [1, 2]},
#  'reed': {'freq': 1, 'doc': [1]},
#  'case': {'freq': 1, 'doc': [1]},
#  'oboes': {'freq': 1, 'doc': [1]},
#  'clarinets': {'freq': 1, 'doc': [1]},
#  'air': {'freq': 1, 'doc': [1]},
#  'column': {'freq': 1, 'doc': [1]},
#  'contained': {'freq': 1, 'doc': [1]},
#  'within': {'freq': 2, 'doc': [1, 4]},
#  'transverse': {'freq': 1, 'doc': [1]},
#  'flute': {'freq': 1, 'doc': [1]},
#  'recorder': {'freq': 1, 'doc': [1]},
#  'set': {'freq': 1, 'doc': [2]},
#  'date': {'freq': 2, 'doc': [2]},
#  'beginning': {'freq': 2, 'doc': [2]},
#  'end': {'freq': 3, 'doc': [2]},
#  'artistic': {'freq': 2, 'doc': [2]},
#  'period': {'freq': 5, 'doc': [2]},
#  'change': {'freq': 1, 'doc': [2]},
#  'gradually': {'freq': 1, 'doc': [2]},
#  'exact': {'freq': 1, 'doc': [2]},
#  'periods': {'freq': 1, 'doc': [2]},
#  'taught': {'freq': 1, 'doc': [2]},
#  'school': {'freq': 1, 'doc': [2]},
#  'mostly': {'freq': 2, 'doc': [2]},
#  'arbitrary': {'freq': 1, 'doc': [2]},
#  'art': {'freq': 2, 'doc': [2]},
#  'historians': {'freq': 1, 'doc': [2]},
#  'usually': {'freq': 1, 'doc': [2]},
#  'try': {'freq': 2, 'doc': [2, 6]},
#  'use': {'freq': 1, 'doc': [2]},
#  'major': {'freq': 1, 'doc': [2]},
#  'event': {'freq': 1, 'doc': [2]},
#  'creation': {'freq': 1, 'doc': [2]},
#  'piece': {'freq': 1, 'doc': [2]},
#  'features': {'freq': 2, 'doc': [2]},
#  'characteristics': {'freq': 1, 'doc': [2]},
#  'new': {'freq': 3, 'doc': [2, 6]},
#  'death': {'freq': 2, 'doc': [2]},
#  'representative': {'freq': 1, 'doc': [2]},
#  'character': {'freq': 1, 'doc': [2]},
#  'baroque': {'freq': 2, 'doc': [2]},
#  'widely': {'freq': 1, 'doc': [2]},
#  'thought': {'freq': 1, 'doc': [2]},
#  'start': {'freq': 1, 'doc': [2]},
#  'first': {'freq': 2, 'doc': [2]},
#  'representation': {'freq': 1, 'doc': [2]},
#  'opera': {'freq': 1, 'doc': [2]},
#  'famous': {'freq': 1, 'doc': [2]},
#  'composer': {'freq': 1, 'doc': [2]},
#  'johann': {'freq': 1, 'doc': [2]},
#  'sebastian': {'freq': 1, 'doc': [2]},
#  'bach': {'freq': 2, 'doc': [2]},
#  'however': {'freq': 2, 'doc': [8, 2]},
#  'musical': {'freq': 1, 'doc': [2]},
#  'styles': {'freq': 1, 'doc': [2]},
#  'actually': {'freq': 2, 'doc': [2, 6]},
#  'started': {'freq': 1, 'doc': [2]},
#  'changing': {'freq': 1, 'doc': [2]},
#  'long': {'freq': 1, 'doc': [2]},
#  'passed': {'freq': 1, 'doc': [2]},
#  'away': {'freq': 1, 'doc': [2]},
#  'already': {'freq': 1, 'doc': [2]},
#  'exhibiting': {'freq': 1, 'doc': [2]},
#  'become': {'freq': 1, 'doc': [2]},
#  'known': {'freq': 1, 'doc': [2]},
#  'classical': {'freq': 1, 'doc': [2]},
#  'general': {'freq': 1, 'doc': [2]},
#  'dates': {'freq': 1, 'doc': [2]},
#  'way': {'freq': 1, 'doc': [2]},
#  'remember': {'freq': 1, 'doc': [2]},
#  'came': {'freq': 1, 'doc': [2]},
#  'decades': {'freq': 1, 'doc': [2]},
#  'cover': {'freq': 1, 'doc': [2]},
#  'adults': {'freq': 1, 'doc': [3]},
#  'like': {'freq': 7, 'doc': [8, 3, 4, 5]},
#  'drinking': {'freq': 1, 'doc': [3]},
#  'coffee': {'freq': 2, 'doc': [3]},
#  'tastes': {'freq': 2, 'doc': [3, 4]},
#  'bad': {'freq': 1, 'doc': [3]},
#  'children': {'freq': 1, 'doc': [3]},
#  'generally': {'freq': 2, 'doc': [3]},
#  'sweet': {'freq': 1, 'doc': [3]},
#  'things': {'freq': 1, 'doc': [3]},
#  'probably': {'freq': 1, 'doc': [3]},
#  'growing': {'freq': 1, 'doc': [3]},
#  'sugars': {'freq': 1, 'doc': [3]},
#  'help': {'freq': 2, 'doc': [8, 3]},
#  'growth': {'freq': 1, 'doc': [3]},
#  'bitter': {'freq': 1, 'doc': [3]},
#  'acquired': {'freq': 1, 'doc': [3]},
#  'taste': {'freq': 5, 'doc': [3, 4]},
#  'happens': {'freq': 1, 'doc': [4]},
#  'wine': {'freq': 8, 'doc': [4]},
#  'ages': {'freq': 2, 'doc': [4]},
#  'make': {'freq': 4, 'doc': [9, 4]},
#  'better': {'freq': 4, 'doc': [4]},
#  'chemical': {'freq': 2, 'doc': [4]},
#  'reaction': {'freq': 2, 'doc': [4]},
#  'occurring': {'freq': 1, 'doc': [4]},
#  'changes': {'freq': 1, 'doc': [4]},
#  'flavor': {'freq': 2, 'doc': [9, 4]},
#  'also': {'freq': 2, 'doc': [4, 6]},
#  'affect': {'freq': 2, 'doc': [9, 4]},
#  'feels': {'freq': 1, 'doc': [4]},
#  'inside': {'freq': 2, 'doc': [9, 4]},
#  'mouth': {'freq': 1, 'doc': [4]},
#  'age': {'freq': 1, 'doc': [4]},
#  'though': {'freq': 1, 'doc': [4]},
#  'compound': {'freq': 1, 'doc': [4]},
#  'tannin': {'freq': 1, 'doc': [4]},
#  'big': {'freq': 1, 'doc': [4]},
#  'effect': {'freq': 1, 'doc': [4]},
#  'going': {'freq': 1, 'doc': [4]},
#  'aging': {'freq': 2, 'doc': [4]},
#  'wines': {'freq': 1, 'doc': [4]},
#  'amounts': {'freq': 1, 'doc': [4]},
#  'tannins': {'freq': 1, 'doc': [4]},
#  'equally': {'freq': 1, 'doc': [4]},
#  'exactly': {'freq': 1, 'doc': [5]},
#  'vitamins': {'freq': 3, 'doc': [5]},
#  'kind': {'freq': 1, 'doc': [5]},
#  'nutrition': {'freq': 2, 'doc': [8, 5]},
#  'body': {'freq': 1, 'doc': [5]},
#  'needs': {'freq': 3, 'doc': [8, 5, 7]},
#  'work': {'freq': 1, 'doc': [5]},
#  'properly': {'freq': 1, 'doc': [5]},
#  'need': {'freq': 2, 'doc': [5]},
#  'eat': {'freq': 2, 'doc': [8, 5]},
#  'variety': {'freq': 1, 'doc': [5]},
#  'foods': {'freq': 1, 'doc': [5]},
#  'bunch': {'freq': 1, 'doc': [5]},
#  'main': {'freq': 1, 'doc': [6]},
#  'predators': {'freq': 3, 'doc': [6]},
#  'zealand': {'freq': 2, 'doc': [6]},
#  'birds': {'freq': 6, 'doc': [6]},
#  'compared': {'freq': 1, 'doc': [6]},
#  'places': {'freq': 1, 'doc': [6]},
#  'world': {'freq': 1, 'doc': [6]},
#  'sure': {'freq': 1, 'doc': [6]},
#  'since': {'freq': 1, 'doc': [6]},
#  'island': {'freq': 2, 'doc': [6]},
#  'possible': {'freq': 1, 'doc': [6]},
#  'many': {'freq': 2, 'doc': [9, 6]},
#  'mammalian': {'freq': 1, 'doc': [6]},
#  'could': {'freq': 1, 'doc': [6]},
#  'access': {'freq': 2, 'doc': [8, 6]},
#  'mammals': {'freq': 2, 'doc': [6]},
#  'swim': {'freq': 1, 'doc': [6]},
#  'present': {'freq': 1, 'doc': [6]},
#  'seals': {'freq': 1, 'doc': [6]},
#  'whales': {'freq': 1, 'doc': [6]},
#  'time': {'freq': 3, 'doc': [9, 6]},
#  'ecological': {'freq': 1, 'doc': [6]},
#  'niche': {'freq': 1, 'doc': [6]},
#  'often': {'freq': 2, 'doc': [6]},
#  'occupy': {'freq': 1, 'doc': [6]},
#  'filled': {'freq': 1, 'doc': [6]},
#  'without': {'freq': 1, 'doc': [6]},
#  'traditional': {'freq': 1, 'doc': [6]},
#  'preyed': {'freq': 1, 'doc': [6]},
#  'population': {'freq': 1, 'doc': [6]},
#  'grew': {'freq': 1, 'doc': [6]},
#  'lot': {'freq': 4, 'doc': [8, 9, 6, 7]},
#  'flightless': {'freq': 1, 'doc': [6]},
#  'think': {'freq': 1, 'doc': [6]},
#  'prey': {'freq': 1, 'doc': [6]},
#  'getting': {'freq': 1, 'doc': [6]},
#  'moa': {'freq': 1, 'doc': [6]},
#  'ate': {'freq': 1, 'doc': [6]},
#  'got': {'freq': 1, 'doc': [6]},
#  'haast': {'freq': 1, 'doc': [6]},
#  'eagle': {'freq': 1, 'doc': [6]},
#  'viruses': {'freq': 2, 'doc': [7]},
#  'bacteria': {'freq': 4, 'doc': [7]},
#  'virus': {'freq': 1, 'doc': [7]},
#  'technically': {'freq': 1, 'doc': [7]},
#  'alive': {'freq': 1, 'doc': [7]},
#  'attach': {'freq': 1, 'doc': [7]},
#  'living': {'freq': 2, 'doc': [7]},
#  'host': {'freq': 1, 'doc': [7]},
#  'able': {'freq': 1, 'doc': [7]},
#  'reproduce': {'freq': 1, 'doc': [7]},
#  'organisms': {'freq': 1, 'doc': [7]},
#  'cause': {'freq': 1, 'doc': [7]},
#  'disease': {'freq': 1, 'doc': [7]},
#  'helpful': {'freq': 1, 'doc': [7]},
#  'well': {'freq': 1, 'doc': [7]},
#  'herbivore': {'freq': 1, 'doc': [8]},
#  'eats': {'freq': 2, 'doc': [8]},
#  'plants': {'freq': 4, 'doc': [8]},
#  'get': {'freq': 2, 'doc': [8]},
#  'protein': {'freq': 3, 'doc': [8]},
#  'survive': {'freq': 1, 'doc': [8]},
#  'grass': {'freq': 2, 'doc': [8]},
#  'herbivores': {'freq': 2, 'doc': [8]},
#  'unlike': {'freq': 1, 'doc': [8]},
#  'digestive': {'freq': 2, 'doc': [8]},
#  'systems': {'freq': 2, 'doc': [8]},
#  'let': {'freq': 1, 'doc': [8]},
#  'contain': {'freq': 1, 'doc': [8]},
#  'cellulose': {'freq': 3, 'doc': [8]},
#  'difficult': {'freq': 1, 'doc': [8]},
#  'digest': {'freq': 1, 'doc': [8]},
#  'cows': {'freq': 2, 'doc': [8]},
#  'process': {'freq': 1, 'doc': [8]},
#  'protected': {'freq': 1, 'doc': [8]},
#  'plant': {'freq': 1, 'doc': [8]},
#  'multiple': {'freq': 1, 'doc': [8]},
#  'stomachs': {'freq': 1, 'doc': [8]},
#  'areas': {'freq': 1, 'doc': [8]},
#  'stomach': {'freq': 1, 'doc': [8]},
#  'intestine': {'freq': 1, 'doc': [8]},
#  'digesting': {'freq': 1, 'doc': [8]},
#  'chocolate': {'freq': 5, 'doc': [9]},
#  'steps': {'freq': 1, 'doc': [9]},
#  'making': {'freq': 1, 'doc': [9]},
#  'cocoa': {'freq': 4, 'doc': [9]},
#  'tree': {'freq': 1, 'doc': [9]},
#  'harvested': {'freq': 1, 'doc': [9]},
#  'produce': {'freq': 1, 'doc': [9]},
#  'pods': {'freq': 2, 'doc': [9]},
#  'pulp': {'freq': 1, 'doc': [9]},
#  'fermented': {'freq': 1, 'doc': [9]},
#  'beans': {'freq': 3, 'doc': [9]},
#  'dried': {'freq': 1, 'doc': [9]},
#  'sun': {'freq': 1, 'doc': [9]},
#  'roasted': {'freq': 2, 'doc': [9]},
#  'step': {'freq': 1, 'doc': [9]},
#  'variability': {'freq': 1, 'doc': [9]},
#  'temperature': {'freq': 1, 'doc': [9]},
#  'roast': {'freq': 1, 'doc': [9]},
#  'processed': {'freq': 1, 'doc': [9]},
#  'remove': {'freq': 1, 'doc': [9]},
#  'shell': {'freq': 1, 'doc': [9]},
#  'nibs': {'freq': 1, 'doc': [9]},
#  'ground': {'freq': 1, 'doc': [9]},
#  'tempered': {'freq': 1, 'doc': [9]},
#  'form': {'freq': 1, 'doc': [9]},
#  'texture': {'freq': 1, 'doc': [9]},
#  'finally': {'freq': 1, 'doc': [9]},
#  'molded': {'freq': 1, 'doc': [9]},
#  'bar': {'freq': 1, 'doc': [9]}}

# %%
inverted_json_keys = list(inverted_json.keys())

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.children = {}
        self.end = False
        self.suggestion_list = []
        self.base = ''
        
class Trie:
    def __init__(self):
        self.root = TreeNode('')
        
    def insert(self, word):
        root = self.root
        for index, letter in enumerate(word):
            if letter not in root.children:
                root.children[letter] = TreeNode(letter)
            root = root.children[letter]
        if index == len(word)-1: root.end = True

# %%
# All keywords formed in a trie ds
trie_root_node = Trie()

for word in inverted_json_keys:
    trie_root_node.insert(word)
    
prefix_hash_table = {}

# Organising the Tries
def dfs(root, curr_word=''):
    root.base = curr_word
    prefix_hash_table[root.base] = root.suggestion_list
    if root.end: 
        root.suggestion_list.append(curr_word)
        return [curr_word]
    
    for val, node in root.children.items():
        to_return = dfs(node, curr_word+node.val)
        root.suggestion_list += to_return
    
    return root.suggestion_list
        
dfs(trie_root_node.root)

# Remove the null entry
prefix_hash_table.pop('', None)
# Out:
# ['different',
#  'difference',
#  'difficult',
#  'directed',
#  'disease',
#  'digest',
#  'depends',
#  'death',
#  'decades',
#  'date',
#  'drinking',
#  'dried',
#  'animal',
#  'amplify',
#  'amounts',
#  'air',
#  'art',
#  'arbitrary',
#  'areas',
#  'actually',
#  'acquired',
#  'access',
#  'away',
#  'already',
#  'also',
#  'alive',
#  'adults',
#  'age',
#  'aging',
#  'affect',
#  'ate',
#  'attach',
#  'able',
#  'perceive',
#  'perception',
#  'period',
#  'part',
#  'passed',
#  'produce',
#  'probably',
#  'properly',
#  'protein',
#  'protected',
#  'process',
#  'predators',
#  'present',
#  'prey',
#  'piece',
#  'places',
#  'plant',
#  'possible',
#  'population',
#  'pods',
#  'pulp',
#  'color',
#  'column',
#  'cone',
#  'contrary',
#  'contain',
#  'corresponds',
#  'combines',
#  'composer',
#  'compound',
#  'compared',
#  'cover',
#  'coffee',
#  'could',
#  'cows',
#  'cocoa',
#  'cell',
#  'called',
#  'case',
#  'came',
#  'cause',
#  'classified',
#  'classical',
#  'clarinets',
#  'create',
#  'creation',
#  'change',
#  'changing',
#  'character',
#  'children',
#  'chemical',
#  'chocolate',
#  'large',
#  'lack',
#  'light',
#  'lips',
#  'like',
#  'living',
#  'leading',
#  'let',
#  'long',
#  'lot',
#  'including',
#  'information',
#  'instruments',
#  'inside',
#  'intestine',
#  'island',
#  'humans',
#  'hit',
#  'historians',
#  'hand',
#  'happen',
#  'haast',
#  'harvested',
#  'however',
#  'host',
#  'help',
#  'herbivore',
#  'special',
#  'specific',
#  'species',
#  'sends',
#  'sees',
#  'set',
#  'sebastian',
#  'seals',
#  'signal',
#  'since',
#  'suggests',
#  'sugars',
#  'sure',
#  'survive',
#  'sun',
#  'sound',
#  'school',
#  'start',
#  'styles',
#  'stomach',
#  'step',
#  'sweet',
#  'swim',
#  'systems',
#  'shell',
#  'back',
#  'bach',
#  'bacteria',
#  'bar',
#  'bad',
#  'brain',
#  'brass',
#  'blindness',
#  'bird',
#  'bitter',
#  'big',
#  'beginning',
#  'become',
#  'better',
#  'beans',
#  'body',
#  'bunch',
#  'eyes',
#  'example',
#  'exact',
#  'exhibiting',
#  'end',
#  'event',
#  'effect',
#  'equally',
#  'eat',
#  'eagle',
#  'ecological',
#  'type',
#  'three',
#  'though',
#  'things',
#  'think',
#  'transverse',
#  'traditional',
#  'try',
#  'tree',
#  'taught',
#  'taste',
#  'tannin',
#  'time',
#  'technically',
#  'temperature',
#  'tempered',
#  'texture',
#  'react',
#  'red',
#  'reed',
#  'recorder',
#  'representative',
#  'representation',
#  'reproduce',
#  'remember',
#  'remove',
#  'rainbow',
#  'range',
#  'rather',
#  'right',
#  'roast',
#  'wavelength',
#  'way',
#  'whose',
#  'whales',
#  'woodwinds',
#  'work',
#  'world',
#  'wind',
#  'wine',
#  'within',
#  'without',
#  'widely',
#  'well',
#  'full',
#  'fish',
#  'first',
#  'filled',
#  'finally',
#  'four',
#  'foods',
#  'form',
#  'flute',
#  'flavor',
#  'flightless',
#  'features',
#  'feels',
#  'fermented',
#  'famous',
#  'number',
#  'nutrition',
#  'name',
#  'new',
#  'need',
#  'niche',
#  'nibs',
#  'violet',
#  'vibrating',
#  'vitamins',
#  'virus',
#  'variety',
#  'variability',
#  'green',
#  'grew',
#  'gradually',
#  'grass',
#  'growing',
#  'growth',
#  'ground',
#  'giving',
#  'general',
#  'get',
#  'going',
#  'got',
#  'yellow',
#  'us',
#  'unlike',
#  'one',
#  'oboes',
#  'opera',
#  'occurring',
#  'occupy',
#  'often',
#  'organisms',
#  'made',
#  'material',
#  'major',
#  'make',
#  'making',
#  'main',
#  'many',
#  'mammalian',
#  'mammals',
#  'metal',
#  'modify',
#  'mostly',
#  'mouth',
#  'moa',
#  'molded',
#  'musical',
#  'multiple',
#  'johann',
#  'known',
#  'kind',
#  'zealand']

# %%
# View All suggestion list
def dfs(root, curr_word=''):
    print(f'root: {root.val}, base: {root.base}, suggestion_list: {root.suggestion_list}')
    for val, node in root.children.items():
        dfs(node, curr_word)
        
dfs(trie_root_node.root)
# Out:
# root: , base: , suggestion_list: ['different', 'difference', 'difficult', 'directed', 'disease', 'digest', 'depends', 'death', 'decades', 'date', 'drinking', 'dried', 'animal', 'amplify', 'amounts', 'air', 'art', 'arbitrary', 'areas', 'actually', 'acquired', 'access', 'away', 'already', 'also', 'alive', 'adults', 'age', 'aging', 'affect', 'ate', 'attach', 'able', 'perceive', 'perception', 'period', 'part', 'passed', 'produce', 'probably', 'properly', 'protein', 'protected', 'process', 'predators', 'present', 'prey', 'piece', 'places', 'plant', 'possible', 'population', 'pods', 'pulp', 'color', 'column', 'cone', 'contrary', 'contain', 'corresponds', 'combines', 'composer', 'compound', 'compared', 'cover', 'coffee', 'could', 'cows', 'cocoa', 'cell', 'called', 'case', 'came', 'cause', 'classified', 'classical', 'clarinets', 'create', 'creation', 'change', 'changing', 'character', 'children', 'chemical', 'chocolate', 'large', 'lack', 'light', 'lips', 'like', 'living', 'leading', 'let', 'long', 'lot', 'including', 'information', 'instruments', 'inside', 'intestine', 'island', 'humans', 'hit', 'historians', 'hand', 'happen', 'haast', 'harvested', 'however', 'host', 'help', 'herbivore', 'special', 'specific', 'species', 'sends', 'sees', 'set', 'sebastian', 'seals', 'signal', 'since', 'suggests', 'sugars', 'sure', 'survive', 'sun', 'sound', 'school', 'start', 'styles', 'stomach', 'step', 'sweet', 'swim', 'systems', 'shell', 'back', 'bach', 'bacteria', 'bar', 'bad', 'brain', 'brass', 'blindness', 'bird', 'bitter', 'big', 'beginning', 'become', 'better', 'beans', 'body', 'bunch', 'eyes', 'example', 'exact', 'exhibiting', 'end', 'event', 'effect', 'equally', 'eat', 'eagle', 'ecological', 'type', 'three', 'though', 'things', 'think', 'transverse', 'traditional', 'try', 'tree', 'taught', 'taste', 'tannin', 'time', 'technically', 'temperature', 'tempered', 'texture', 'react', 'red', 'reed', 'recorder', 'representative', 'representation', 'reproduce', 'remember', 'remove', 'rainbow', 'range', 'rather', 'right', 'roast', 'wavelength', 'way', 'whose', 'whales', 'woodwinds', 'work', 'world', 'wind', 'wine', 'within', 'without', 'widely', 'well', 'full', 'fish', 'first', 'filled', 'finally', 'four', 'foods', 'form', 'flute', 'flavor', 'flightless', 'features', 'feels', 'fermented', 'famous', 'number', 'nutrition', 'name', 'new', 'need', 'niche', 'nibs', 'violet', 'vibrating', 'vitamins', 'virus', 'variety', 'variability', 'green', 'grew', 'gradually', 'grass', 'growing', 'growth', 'ground', 'giving', 'general', 'get', 'going', 'got', 'yellow', 'us', 'unlike', 'one', 'oboes', 'opera', 'occurring', 'occupy', 'often', 'organisms', 'made', 'material', 'major', 'make', 'making', 'main', 'many', 'mammalian', 'mammals', 'metal', 'modify', 'mostly', 'mouth', 'moa', 'molded', 'musical', 'multiple', 'johann', 'known', 'kind', 'zealand']
# root: d, base: d, suggestion_list: ['different', 'difference', 'difficult', 'directed', 'disease', 'digest', 'depends', 'death', 'decades', 'date', 'drinking', 'dried']
# root: i, base: di, suggestion_list: ['different', 'difference', 'difficult', 'directed', 'disease', 'digest']
# root: f, base: dif, suggestion_list: ['different', 'difference', 'difficult']
# root: f, base: diff, suggestion_list: ['different', 'difference', 'difficult']
# root: e, base: diffe, suggestion_list: ['different', 'difference']
# root: r, base: differ, suggestion_list: ['different', 'difference']
# root: e, base: differe, suggestion_list: ['different', 'difference']
# root: n, base: differen, suggestion_list: ['different', 'difference']
# root: t, base: different, suggestion_list: ['different']
# root: c, base: differenc, suggestion_list: ['difference']
# root: e, base: difference, suggestion_list: ['difference']
# root: i, base: diffi, suggestion_list: ['difficult']
# root: c, base: diffic, suggestion_list: ['difficult']
# root: u, base: difficu, suggestion_list: ['difficult']
# root: l, base: difficul, suggestion_list: ['difficult']
# root: t, base: difficult, suggestion_list: ['difficult']
# root: r, base: dir, suggestion_list: ['directed']
# root: e, base: dire, suggestion_list: ['directed']
# root: c, base: direc, suggestion_list: ['directed']
# root: t, base: direct, suggestion_list: ['directed']
# root: e, base: directe, suggestion_list: ['directed']
# root: d, base: directed, suggestion_list: ['directed']
# root: s, base: dis, suggestion_list: ['disease']
# root: e, base: dise, suggestion_list: ['disease']
# root: a, base: disea, suggestion_list: ['disease']
# root: s, base: diseas, suggestion_list: ['disease']
# root: e, base: disease, suggestion_list: ['disease']
# root: g, base: dig, suggestion_list: ['digest']
# root: e, base: dige, suggestion_list: ['digest']
# root: s, base: diges, suggestion_list: ['digest']
# root: t, base: digest, suggestion_list: ['digest']
# root: i, base: , suggestion_list: []
# root: v, base: , suggestion_list: []
# root: e, base: , suggestion_list: []
# root: n, base: , suggestion_list: []
# root: g, base: , suggestion_list: []
# root: e, base: de, suggestion_list: ['depends', 'death', 'decades']
# root: p, base: dep, suggestion_list: ['depends']
# root: e, base: depe, suggestion_list: ['depends']
# root: n, base: depen, suggestion_list: ['depends']
# root: d, base: depend, suggestion_list: ['depends']
# root: s, base: depends, suggestion_list: ['depends']
# root: a, base: dea, suggestion_list: ['death']
# root: t, base: deat, suggestion_list: ['death']
# root: h, base: death, suggestion_list: ['death']
# root: c, base: dec, suggestion_list: ['decades']
# root: a, base: deca, suggestion_list: ['decades']
# root: d, base: decad, suggestion_list: ['decades']
# root: e, base: decade, suggestion_list: ['decades']
# root: s, base: decades, suggestion_list: ['decades']
# root: a, base: da, suggestion_list: ['date']
# root: t, base: dat, suggestion_list: ['date']
# root: e, base: date, suggestion_list: ['date']
# root: s, base: , suggestion_list: []
# root: r, base: dr, suggestion_list: ['drinking', 'dried']
# root: i, base: dri, suggestion_list: ['drinking', 'dried']
# root: n, base: drin, suggestion_list: ['drinking']
# root: k, base: drink, suggestion_list: ['drinking']
# root: i, base: drinki, suggestion_list: ['drinking']
# root: n, base: drinkin, suggestion_list: ['drinking']
# root: g, base: drinking, suggestion_list: ['drinking']
# root: e, base: drie, suggestion_list: ['dried']
# root: d, base: dried, suggestion_list: ['dried']
# root: a, base: a, suggestion_list: ['animal', 'amplify', 'amounts', 'air', 'art', 'arbitrary', 'areas', 'actually', 'acquired', 'access', 'away', 'already', 'also', 'alive', 'adults', 'age', 'aging', 'affect', 'ate', 'attach', 'able']
# root: n, base: an, suggestion_list: ['animal']
# root: i, base: ani, suggestion_list: ['animal']
# root: m, base: anim, suggestion_list: ['animal']
# root: a, base: anima, suggestion_list: ['animal']
# root: l, base: animal, suggestion_list: ['animal']
# root: s, base: , suggestion_list: []
# root: m, base: am, suggestion_list: ['amplify', 'amounts']
# root: p, base: amp, suggestion_list: ['amplify']
# root: l, base: ampl, suggestion_list: ['amplify']
# root: i, base: ampli, suggestion_list: ['amplify']
# root: f, base: amplif, suggestion_list: ['amplify']
# root: y, base: amplify, suggestion_list: ['amplify']
# root: o, base: amo, suggestion_list: ['amounts']
# root: u, base: amou, suggestion_list: ['amounts']
# root: n, base: amoun, suggestion_list: ['amounts']
# root: t, base: amount, suggestion_list: ['amounts']
# root: s, base: amounts, suggestion_list: ['amounts']
# root: i, base: ai, suggestion_list: ['air']
# root: r, base: air, suggestion_list: ['air']
# root: r, base: ar, suggestion_list: ['art', 'arbitrary', 'areas']
# root: t, base: art, suggestion_list: ['art']
# root: i, base: , suggestion_list: []
# root: s, base: , suggestion_list: []
# root: t, base: , suggestion_list: []
# root: i, base: , suggestion_list: []
# root: c, base: , suggestion_list: []
# root: b, base: arb, suggestion_list: ['arbitrary']
# root: i, base: arbi, suggestion_list: ['arbitrary']
# root: t, base: arbit, suggestion_list: ['arbitrary']
# root: r, base: arbitr, suggestion_list: ['arbitrary']
# root: a, base: arbitra, suggestion_list: ['arbitrary']
# root: r, base: arbitrar, suggestion_list: ['arbitrary']
# root: y, base: arbitrary, suggestion_list: ['arbitrary']
# root: e, base: are, suggestion_list: ['areas']
# root: a, base: area, suggestion_list: ['areas']
# root: s, base: areas, suggestion_list: ['areas']
# root: c, base: ac, suggestion_list: ['actually', 'acquired', 'access']
# root: t, base: act, suggestion_list: ['actually']
# root: u, base: actu, suggestion_list: ['actually']
# root: a, base: actua, suggestion_list: ['actually']
# root: l, base: actual, suggestion_list: ['actually']
# root: l, base: actuall, suggestion_list: ['actually']
# root: y, base: actually, suggestion_list: ['actually']
# root: q, base: acq, suggestion_list: ['acquired']
# root: u, base: acqu, suggestion_list: ['acquired']
# root: i, base: acqui, suggestion_list: ['acquired']
# root: r, base: acquir, suggestion_list: ['acquired']
# root: e, base: acquire, suggestion_list: ['acquired']
# root: d, base: acquired, suggestion_list: ['acquired']
# root: c, base: acc, suggestion_list: ['access']
# root: e, base: acce, suggestion_list: ['access']
# root: s, base: acces, suggestion_list: ['access']
# root: s, base: access, suggestion_list: ['access']
# root: w, base: aw, suggestion_list: ['away']
# root: a, base: awa, suggestion_list: ['away']
# root: y, base: away, suggestion_list: ['away']
# root: l, base: al, suggestion_list: ['already', 'also', 'alive']
# root: r, base: alr, suggestion_list: ['already']
# root: e, base: alre, suggestion_list: ['already']
# root: a, base: alrea, suggestion_list: ['already']
# root: d, base: alread, suggestion_list: ['already']
# root: y, base: already, suggestion_list: ['already']
# root: s, base: als, suggestion_list: ['also']
# root: o, base: also, suggestion_list: ['also']
# root: i, base: ali, suggestion_list: ['alive']
# root: v, base: aliv, suggestion_list: ['alive']
# root: e, base: alive, suggestion_list: ['alive']
# root: d, base: ad, suggestion_list: ['adults']
# root: u, base: adu, suggestion_list: ['adults']
# root: l, base: adul, suggestion_list: ['adults']
# root: t, base: adult, suggestion_list: ['adults']
# root: s, base: adults, suggestion_list: ['adults']
# root: g, base: ag, suggestion_list: ['age', 'aging']
# root: e, base: age, suggestion_list: ['age']
# root: s, base: , suggestion_list: []
# root: i, base: agi, suggestion_list: ['aging']
# root: n, base: agin, suggestion_list: ['aging']
# root: g, base: aging, suggestion_list: ['aging']
# root: f, base: af, suggestion_list: ['affect']
# root: f, base: aff, suggestion_list: ['affect']
# root: e, base: affe, suggestion_list: ['affect']
# root: c, base: affec, suggestion_list: ['affect']
# root: t, base: affect, suggestion_list: ['affect']
# root: t, base: at, suggestion_list: ['ate', 'attach']
# root: e, base: ate, suggestion_list: ['ate']
# root: t, base: att, suggestion_list: ['attach']
# root: a, base: atta, suggestion_list: ['attach']
# root: c, base: attac, suggestion_list: ['attach']
# root: h, base: attach, suggestion_list: ['attach']
# root: b, base: ab, suggestion_list: ['able']
# root: l, base: abl, suggestion_list: ['able']
# root: e, base: able, suggestion_list: ['able']
# root: p, base: p, suggestion_list: ['perceive', 'perception', 'period', 'part', 'passed', 'produce', 'probably', 'properly', 'protein', 'protected', 'process', 'predators', 'present', 'prey', 'piece', 'places', 'plant', 'possible', 'population', 'pods', 'pulp']
# root: e, base: pe, suggestion_list: ['perceive', 'perception', 'period']
# root: r, base: per, suggestion_list: ['perceive', 'perception', 'period']
# root: c, base: perc, suggestion_list: ['perceive', 'perception']
# root: e, base: perce, suggestion_list: ['perceive', 'perception']
# root: i, base: percei, suggestion_list: ['perceive']
# root: v, base: perceiv, suggestion_list: ['perceive']
# root: e, base: perceive, suggestion_list: ['perceive']
# root: p, base: percep, suggestion_list: ['perception']
# root: t, base: percept, suggestion_list: ['perception']
# root: i, base: percepti, suggestion_list: ['perception']
# root: o, base: perceptio, suggestion_list: ['perception']
# root: n, base: perception, suggestion_list: ['perception']
# root: i, base: peri, suggestion_list: ['period']
# root: o, base: perio, suggestion_list: ['period']
# root: d, base: period, suggestion_list: ['period']
# root: s, base: , suggestion_list: []
# root: a, base: pa, suggestion_list: ['part', 'passed']
# root: r, base: par, suggestion_list: ['part']
# root: t, base: part, suggestion_list: ['part']
# root: s, base: pas, suggestion_list: ['passed']
# root: s, base: pass, suggestion_list: ['passed']
# root: e, base: passe, suggestion_list: ['passed']
# root: d, base: passed, suggestion_list: ['passed']
# root: r, base: pr, suggestion_list: ['produce', 'probably', 'properly', 'protein', 'protected', 'process', 'predators', 'present', 'prey']
# root: o, base: pro, suggestion_list: ['produce', 'probably', 'properly', 'protein', 'protected', 'process']
# root: d, base: prod, suggestion_list: ['produce']
# root: u, base: produ, suggestion_list: ['produce']
# root: c, base: produc, suggestion_list: ['produce']
# root: e, base: produce, suggestion_list: ['produce']
# root: d, base: , suggestion_list: []
# root: b, base: prob, suggestion_list: ['probably']
# root: a, base: proba, suggestion_list: ['probably']
# root: b, base: probab, suggestion_list: ['probably']
# root: l, base: probabl, suggestion_list: ['probably']
# root: y, base: probably, suggestion_list: ['probably']
# root: p, base: prop, suggestion_list: ['properly']
# root: e, base: prope, suggestion_list: ['properly']
# root: r, base: proper, suggestion_list: ['properly']
# root: l, base: properl, suggestion_list: ['properly']
# root: y, base: properly, suggestion_list: ['properly']
# root: t, base: prot, suggestion_list: ['protein', 'protected']
# root: e, base: prote, suggestion_list: ['protein', 'protected']
# root: i, base: protei, suggestion_list: ['protein']
# root: n, base: protein, suggestion_list: ['protein']
# root: c, base: protec, suggestion_list: ['protected']
# root: t, base: protect, suggestion_list: ['protected']
# root: e, base: protecte, suggestion_list: ['protected']
# root: d, base: protected, suggestion_list: ['protected']
# root: c, base: proc, suggestion_list: ['process']
# root: e, base: proce, suggestion_list: ['process']
# root: s, base: proces, suggestion_list: ['process']
# root: s, base: process, suggestion_list: ['process']
# root: e, base: , suggestion_list: []
# root: d, base: , suggestion_list: []
# root: e, base: pre, suggestion_list: ['predators', 'present', 'prey']
# root: d, base: pred, suggestion_list: ['predators']
# root: a, base: preda, suggestion_list: ['predators']
# root: t, base: predat, suggestion_list: ['predators']
# root: o, base: predato, suggestion_list: ['predators']
# root: r, base: predator, suggestion_list: ['predators']
# root: s, base: predators, suggestion_list: ['predators']
# root: s, base: pres, suggestion_list: ['present']
# root: e, base: prese, suggestion_list: ['present']
# root: n, base: presen, suggestion_list: ['present']
# root: t, base: present, suggestion_list: ['present']
# root: y, base: prey, suggestion_list: ['prey']
# root: e, base: , suggestion_list: []
# root: d, base: , suggestion_list: []
# root: i, base: pi, suggestion_list: ['piece']
# root: e, base: pie, suggestion_list: ['piece']
# root: c, base: piec, suggestion_list: ['piece']
# root: e, base: piece, suggestion_list: ['piece']
# root: l, base: pl, suggestion_list: ['places', 'plant']
# root: a, base: pla, suggestion_list: ['places', 'plant']
# root: c, base: plac, suggestion_list: ['places']
# root: e, base: place, suggestion_list: ['places']
# root: s, base: places, suggestion_list: ['places']
# root: n, base: plan, suggestion_list: ['plant']
# root: t, base: plant, suggestion_list: ['plant']
# root: s, base: , suggestion_list: []
# root: o, base: po, suggestion_list: ['possible', 'population', 'pods']
# root: s, base: pos, suggestion_list: ['possible']
# root: s, base: poss, suggestion_list: ['possible']
# root: i, base: possi, suggestion_list: ['possible']
# root: b, base: possib, suggestion_list: ['possible']
# root: l, base: possibl, suggestion_list: ['possible']
# root: e, base: possible, suggestion_list: ['possible']
# root: p, base: pop, suggestion_list: ['population']
# root: u, base: popu, suggestion_list: ['population']
# root: l, base: popul, suggestion_list: ['population']
# root: a, base: popula, suggestion_list: ['population']
# root: t, base: populat, suggestion_list: ['population']
# root: i, base: populati, suggestion_list: ['population']
# root: o, base: populatio, suggestion_list: ['population']
# root: n, base: population, suggestion_list: ['population']
# root: d, base: pod, suggestion_list: ['pods']
# root: s, base: pods, suggestion_list: ['pods']
# root: u, base: pu, suggestion_list: ['pulp']
# root: l, base: pul, suggestion_list: ['pulp']
# root: p, base: pulp, suggestion_list: ['pulp']
# root: c, base: c, suggestion_list: ['color', 'column', 'cone', 'contrary', 'contain', 'corresponds', 'combines', 'composer', 'compound', 'compared', 'cover', 'coffee', 'could', 'cows', 'cocoa', 'cell', 'called', 'case', 'came', 'cause', 'classified', 'classical', 'clarinets', 'create', 'creation', 'change', 'changing', 'character', 'children', 'chemical', 'chocolate']
# root: o, base: co, suggestion_list: ['color', 'column', 'cone', 'contrary', 'contain', 'corresponds', 'combines', 'composer', 'compound', 'compared', 'cover', 'coffee', 'could', 'cows', 'cocoa']
# root: l, base: col, suggestion_list: ['color', 'column']
# root: o, base: colo, suggestion_list: ['color']
# root: r, base: color, suggestion_list: ['color']
# root: s, base: , suggestion_list: []
# root: u, base: colu, suggestion_list: ['column']
# root: m, base: colum, suggestion_list: ['column']
# root: n, base: column, suggestion_list: ['column']
# root: n, base: con, suggestion_list: ['cone', 'contrary', 'contain']
# root: e, base: cone, suggestion_list: ['cone']
# root: t, base: cont, suggestion_list: ['contrary', 'contain']
# root: r, base: contr, suggestion_list: ['contrary']
# root: a, base: contra, suggestion_list: ['contrary']
# root: r, base: contrar, suggestion_list: ['contrary']
# root: y, base: contrary, suggestion_list: ['contrary']
# root: a, base: conta, suggestion_list: ['contain']
# root: i, base: contai, suggestion_list: ['contain']
# root: n, base: contain, suggestion_list: ['contain']
# root: e, base: , suggestion_list: []
# root: d, base: , suggestion_list: []
# root: r, base: cor, suggestion_list: ['corresponds']
# root: r, base: corr, suggestion_list: ['corresponds']
# root: e, base: corre, suggestion_list: ['corresponds']
# root: s, base: corres, suggestion_list: ['corresponds']
# root: p, base: corresp, suggestion_list: ['corresponds']
# root: o, base: correspo, suggestion_list: ['corresponds']
# root: n, base: correspon, suggestion_list: ['corresponds']
# root: d, base: correspond, suggestion_list: ['corresponds']
# root: s, base: corresponds, suggestion_list: ['corresponds']
# root: m, base: com, suggestion_list: ['combines', 'composer', 'compound', 'compared']
# root: b, base: comb, suggestion_list: ['combines']
# root: i, base: combi, suggestion_list: ['combines']
# root: n, base: combin, suggestion_list: ['combines']
# root: e, base: combine, suggestion_list: ['combines']
# root: s, base: combines, suggestion_list: ['combines']
# root: p, base: comp, suggestion_list: ['composer', 'compound', 'compared']
# root: o, base: compo, suggestion_list: ['composer', 'compound']
# root: s, base: compos, suggestion_list: ['composer']
# root: e, base: compose, suggestion_list: ['composer']
# root: r, base: composer, suggestion_list: ['composer']
# root: u, base: compou, suggestion_list: ['compound']
# root: n, base: compoun, suggestion_list: ['compound']
# root: d, base: compound, suggestion_list: ['compound']
# root: a, base: compa, suggestion_list: ['compared']
# root: r, base: compar, suggestion_list: ['compared']
# root: e, base: compare, suggestion_list: ['compared']
# root: d, base: compared, suggestion_list: ['compared']
# root: v, base: cov, suggestion_list: ['cover']
# root: e, base: cove, suggestion_list: ['cover']
# root: r, base: cover, suggestion_list: ['cover']
# root: f, base: cof, suggestion_list: ['coffee']
# root: f, base: coff, suggestion_list: ['coffee']
# root: e, base: coffe, suggestion_list: ['coffee']
# root: e, base: coffee, suggestion_list: ['coffee']
# root: u, base: cou, suggestion_list: ['could']
# root: l, base: coul, suggestion_list: ['could']
# root: d, base: could, suggestion_list: ['could']
# root: w, base: cow, suggestion_list: ['cows']
# root: s, base: cows, suggestion_list: ['cows']
# root: c, base: coc, suggestion_list: ['cocoa']
# root: o, base: coco, suggestion_list: ['cocoa']
# root: a, base: cocoa, suggestion_list: ['cocoa']
# root: e, base: ce, suggestion_list: ['cell']
# root: l, base: cel, suggestion_list: ['cell']
# root: l, base: cell, suggestion_list: ['cell']
# root: s, base: , suggestion_list: []
# root: u, base: , suggestion_list: []
# root: l, base: , suggestion_list: []
# root: o, base: , suggestion_list: []
# root: s, base: , suggestion_list: []
# root: e, base: , suggestion_list: []
# root: a, base: ca, suggestion_list: ['called', 'case', 'came', 'cause']
# root: l, base: cal, suggestion_list: ['called']
# root: l, base: call, suggestion_list: ['called']
# root: e, base: calle, suggestion_list: ['called']
# root: d, base: called, suggestion_list: ['called']
# root: s, base: cas, suggestion_list: ['case']
# root: e, base: case, suggestion_list: ['case']
# root: m, base: cam, suggestion_list: ['came']
# root: e, base: came, suggestion_list: ['came']
# root: u, base: cau, suggestion_list: ['cause']
# root: s, base: caus, suggestion_list: ['cause']
# root: e, base: cause, suggestion_list: ['cause']
# root: l, base: cl, suggestion_list: ['classified', 'classical', 'clarinets']
# root: a, base: cla, suggestion_list: ['classified', 'classical', 'clarinets']
# root: s, base: clas, suggestion_list: ['classified', 'classical']
# root: s, base: class, suggestion_list: ['classified', 'classical']
# root: i, base: classi, suggestion_list: ['classified', 'classical']
# root: f, base: classif, suggestion_list: ['classified']
# root: i, base: classifi, suggestion_list: ['classified']
# root: e, base: classifie, suggestion_list: ['classified']
# root: d, base: classified, suggestion_list: ['classified']
# root: c, base: classic, suggestion_list: ['classical']
# root: a, base: classica, suggestion_list: ['classical']
# root: l, base: classical, suggestion_list: ['classical']
# root: r, base: clar, suggestion_list: ['clarinets']
# root: i, base: clari, suggestion_list: ['clarinets']
# root: n, base: clarin, suggestion_list: ['clarinets']
# root: e, base: clarine, suggestion_list: ['clarinets']
# root: t, base: clarinet, suggestion_list: ['clarinets']
# root: s, base: clarinets, suggestion_list: ['clarinets']
# root: r, base: cr, suggestion_list: ['create', 'creation']
# root: e, base: cre, suggestion_list: ['create', 'creation']
# root: a, base: crea, suggestion_list: ['create', 'creation']
# root: t, base: creat, suggestion_list: ['create', 'creation']
# root: e, base: create, suggestion_list: ['create']
# root: i, base: creati, suggestion_list: ['creation']
# root: o, base: creatio, suggestion_list: ['creation']
# root: n, base: creation, suggestion_list: ['creation']
# root: h, base: ch, suggestion_list: ['change', 'changing', 'character', 'children', 'chemical', 'chocolate']
# root: a, base: cha, suggestion_list: ['change', 'changing', 'character']
# root: n, base: chan, suggestion_list: ['change', 'changing']
# root: g, base: chang, suggestion_list: ['change', 'changing']
# root: e, base: change, suggestion_list: ['change']
# root: s, base: , suggestion_list: []
# root: i, base: changi, suggestion_list: ['changing']
# root: n, base: changin, suggestion_list: ['changing']
# root: g, base: changing, suggestion_list: ['changing']
# root: r, base: char, suggestion_list: ['character']
# root: a, base: chara, suggestion_list: ['character']
# root: c, base: charac, suggestion_list: ['character']
# root: t, base: charact, suggestion_list: ['character']
# root: e, base: characte, suggestion_list: ['character']
# root: r, base: character, suggestion_list: ['character']
# root: i, base: , suggestion_list: []
# root: s, base: , suggestion_list: []
# root: t, base: , suggestion_list: []
# root: i, base: , suggestion_list: []
# root: c, base: , suggestion_list: []
# root: s, base: , suggestion_list: []
# root: i, base: chi, suggestion_list: ['children']
# root: l, base: chil, suggestion_list: ['children']
# root: d, base: child, suggestion_list: ['children']
# root: r, base: childr, suggestion_list: ['children']
# root: e, base: childre, suggestion_list: ['children']
# root: n, base: children, suggestion_list: ['children']
# root: e, base: che, suggestion_list: ['chemical']
# root: m, base: chem, suggestion_list: ['chemical']
# root: i, base: chemi, suggestion_list: ['chemical']
# root: c, base: chemic, suggestion_list: ['chemical']
# root: a, base: chemica, suggestion_list: ['chemical']
# root: l, base: chemical, suggestion_list: ['chemical']
# root: o, base: cho, suggestion_list: ['chocolate']
# root: c, base: choc, suggestion_list: ['chocolate']
# root: o, base: choco, suggestion_list: ['chocolate']
# root: l, base: chocol, suggestion_list: ['chocolate']
# root: a, base: chocola, suggestion_list: ['chocolate']
# root: t, base: chocolat, suggestion_list: ['chocolate']
# root: e, base: chocolate, suggestion_list: ['chocolate']
# root: l, base: l, suggestion_list: ['large', 'lack', 'light', 'lips', 'like', 'living', 'leading', 'let', 'long', 'lot']
# root: a, base: la, suggestion_list: ['large', 'lack']
# root: r, base: lar, suggestion_list: ['large']
# root: g, base: larg, suggestion_list: ['large']
# root: e, base: large, suggestion_list: ['large']
# root: r, base: , suggestion_list: []
# root: c, base: lac, suggestion_list: ['lack']
# root: k, base: lack, suggestion_list: ['lack']
# root: i, base: li, suggestion_list: ['light', 'lips', 'like', 'living']
# root: g, base: lig, suggestion_list: ['light']
# root: h, base: ligh, suggestion_list: ['light']
# root: t, base: light, suggestion_list: ['light']
# root: p, base: lip, suggestion_list: ['lips']
# root: s, base: lips, suggestion_list: ['lips']
# root: k, base: lik, suggestion_list: ['like']
# root: e, base: like, suggestion_list: ['like']
# root: v, base: liv, suggestion_list: ['living']
# root: i, base: livi, suggestion_list: ['living']
# root: n, base: livin, suggestion_list: ['living']
# root: g, base: living, suggestion_list: ['living']
# root: e, base: le, suggestion_list: ['leading', 'let']
# root: a, base: lea, suggestion_list: ['leading']
# root: d, base: lead, suggestion_list: ['leading']
# root: i, base: leadi, suggestion_list: ['leading']
# root: n, base: leadin, suggestion_list: ['leading']
# root: g, base: leading, suggestion_list: ['leading']
# root: t, base: let, suggestion_list: ['let']
# root: o, base: lo, suggestion_list: ['long', 'lot']
# root: n, base: lon, suggestion_list: ['long']
# root: g, base: long, suggestion_list: ['long']
# root: t, base: lot, suggestion_list: ['lot']
# root: i, base: i, suggestion_list: ['including', 'information', 'instruments', 'inside', 'intestine', 'island']
# root: n, base: in, suggestion_list: ['including', 'information', 'instruments', 'inside', 'intestine']
# root: c, base: inc, suggestion_list: ['including']
# root: l, base: incl, suggestion_list: ['including']
# root: u, base: inclu, suggestion_list: ['including']
# root: d, base: includ, suggestion_list: ['including']
# root: i, base: includi, suggestion_list: ['including']
# root: n, base: includin, suggestion_list: ['including']
# root: g, base: including, suggestion_list: ['including']
# root: f, base: inf, suggestion_list: ['information']
# root: o, base: info, suggestion_list: ['information']
# root: r, base: infor, suggestion_list: ['information']
# root: m, base: inform, suggestion_list: ['information']
# root: a, base: informa, suggestion_list: ['information']
# root: t, base: informat, suggestion_list: ['information']
# root: i, base: informati, suggestion_list: ['information']
# root: o, base: informatio, suggestion_list: ['information']
# root: n, base: information, suggestion_list: ['information']
# root: s, base: ins, suggestion_list: ['instruments', 'inside']
# root: t, base: inst, suggestion_list: ['instruments']
# root: r, base: instr, suggestion_list: ['instruments']
# root: u, base: instru, suggestion_list: ['instruments']
# root: m, base: instrum, suggestion_list: ['instruments']
# root: e, base: instrume, suggestion_list: ['instruments']
# root: n, base: instrumen, suggestion_list: ['instruments']
# root: t, base: instrument, suggestion_list: ['instruments']
# root: s, base: instruments, suggestion_list: ['instruments']
# root: i, base: insi, suggestion_list: ['inside']
# root: d, base: insid, suggestion_list: ['inside']
# root: e, base: inside, suggestion_list: ['inside']
# root: t, base: int, suggestion_list: ['intestine']
# root: e, base: inte, suggestion_list: ['intestine']
# root: s, base: intes, suggestion_list: ['intestine']
# root: t, base: intest, suggestion_list: ['intestine']
# root: i, base: intesti, suggestion_list: ['intestine']
# root: n, base: intestin, suggestion_list: ['intestine']
# root: e, base: intestine, suggestion_list: ['intestine']
# root: s, base: is, suggestion_list: ['island']
# root: l, base: isl, suggestion_list: ['island']
# root: a, base: isla, suggestion_list: ['island']
# root: n, base: islan, suggestion_list: ['island']
# root: d, base: island, suggestion_list: ['island']
# root: h, base: h, suggestion_list: ['humans', 'hit', 'historians', 'hand', 'happen', 'haast', 'harvested', 'however', 'host', 'help', 'herbivore']
# root: u, base: hu, suggestion_list: ['humans']
# root: m, base: hum, suggestion_list: ['humans']
# root: a, base: huma, suggestion_list: ['humans']
# root: n, base: human, suggestion_list: ['humans']
# root: s, base: humans, suggestion_list: ['humans']
# root: i, base: hi, suggestion_list: ['hit', 'historians']
# root: t, base: hit, suggestion_list: ['hit']
# root: s, base: his, suggestion_list: ['historians']
# root: t, base: hist, suggestion_list: ['historians']
# root: o, base: histo, suggestion_list: ['historians']
# root: r, base: histor, suggestion_list: ['historians']
# root: i, base: histori, suggestion_list: ['historians']
# root: a, base: historia, suggestion_list: ['historians']
# root: n, base: historian, suggestion_list: ['historians']
# root: s, base: historians, suggestion_list: ['historians']
# root: a, base: ha, suggestion_list: ['hand', 'happen', 'haast', 'harvested']
# root: n, base: han, suggestion_list: ['hand']
# root: d, base: hand, suggestion_list: ['hand']
# root: p, base: hap, suggestion_list: ['happen']
# root: p, base: happ, suggestion_list: ['happen']
# root: e, base: happe, suggestion_list: ['happen']
# root: n, base: happen, suggestion_list: ['happen']
# root: s, base: , suggestion_list: []
# root: a, base: haa, suggestion_list: ['haast']
# root: s, base: haas, suggestion_list: ['haast']
# root: t, base: haast, suggestion_list: ['haast']
# root: r, base: har, suggestion_list: ['harvested']
# root: v, base: harv, suggestion_list: ['harvested']
# root: e, base: harve, suggestion_list: ['harvested']
# root: s, base: harves, suggestion_list: ['harvested']
# root: t, base: harvest, suggestion_list: ['harvested']
# root: e, base: harveste, suggestion_list: ['harvested']
# root: d, base: harvested, suggestion_list: ['harvested']
# root: o, base: ho, suggestion_list: ['however', 'host']
# root: w, base: how, suggestion_list: ['however']
# root: e, base: howe, suggestion_list: ['however']
# root: v, base: howev, suggestion_list: ['however']
# root: e, base: howeve, suggestion_list: ['however']
# root: r, base: however, suggestion_list: ['however']
# root: s, base: hos, suggestion_list: ['host']
# root: t, base: host, suggestion_list: ['host']
# root: e, base: he, suggestion_list: ['help', 'herbivore']
# root: l, base: hel, suggestion_list: ['help']
# root: p, base: help, suggestion_list: ['help']
# root: f, base: , suggestion_list: []
# root: u, base: , suggestion_list: []
# root: l, base: , suggestion_list: []
# root: r, base: her, suggestion_list: ['herbivore']
# root: b, base: herb, suggestion_list: ['herbivore']
# root: i, base: herbi, suggestion_list: ['herbivore']
# root: v, base: herbiv, suggestion_list: ['herbivore']
# root: o, base: herbivo, suggestion_list: ['herbivore']
# root: r, base: herbivor, suggestion_list: ['herbivore']
# root: e, base: herbivore, suggestion_list: ['herbivore']
# root: s, base: , suggestion_list: []
# root: s, base: s, suggestion_list: ['special', 'specific', 'species', 'sends', 'sees', 'set', 'sebastian', 'seals', 'signal', 'since', 'suggests', 'sugars', 'sure', 'survive', 'sun', 'sound', 'school', 'start', 'styles', 'stomach', 'step', 'sweet', 'swim', 'systems', 'shell']
# root: p, base: sp, suggestion_list: ['special', 'specific', 'species']
# root: e, base: spe, suggestion_list: ['special', 'specific', 'species']
# root: c, base: spec, suggestion_list: ['special', 'specific', 'species']
# root: i, base: speci, suggestion_list: ['special', 'specific', 'species']
# root: a, base: specia, suggestion_list: ['special']
# root: l, base: special, suggestion_list: ['special']
# root: f, base: specif, suggestion_list: ['specific']
# root: i, base: specifi, suggestion_list: ['specific']
# root: c, base: specific, suggestion_list: ['specific']
# root: e, base: specie, suggestion_list: ['species']
# root: s, base: species, suggestion_list: ['species']
# root: e, base: se, suggestion_list: ['sends', 'sees', 'set', 'sebastian', 'seals']
# root: n, base: sen, suggestion_list: ['sends']
# root: d, base: send, suggestion_list: ['sends']
# root: s, base: sends, suggestion_list: ['sends']
# root: e, base: see, suggestion_list: ['sees']
# root: s, base: sees, suggestion_list: ['sees']
# root: t, base: set, suggestion_list: ['set']
# root: b, base: seb, suggestion_list: ['sebastian']
# root: a, base: seba, suggestion_list: ['sebastian']
# root: s, base: sebas, suggestion_list: ['sebastian']
# root: t, base: sebast, suggestion_list: ['sebastian']
# root: i, base: sebasti, suggestion_list: ['sebastian']
# root: a, base: sebastia, suggestion_list: ['sebastian']
# root: n, base: sebastian, suggestion_list: ['sebastian']
# root: a, base: sea, suggestion_list: ['seals']
# root: l, base: seal, suggestion_list: ['seals']
# root: s, base: seals, suggestion_list: ['seals']
# root: i, base: si, suggestion_list: ['signal', 'since']
# root: g, base: sig, suggestion_list: ['signal']
# root: n, base: sign, suggestion_list: ['signal']
# root: a, base: signa, suggestion_list: ['signal']
# root: l, base: signal, suggestion_list: ['signal']
# root: n, base: sin, suggestion_list: ['since']
# root: c, base: sinc, suggestion_list: ['since']
# root: e, base: since, suggestion_list: ['since']
# root: u, base: su, suggestion_list: ['suggests', 'sugars', 'sure', 'survive', 'sun']
# root: g, base: sug, suggestion_list: ['suggests', 'sugars']
# root: g, base: sugg, suggestion_list: ['suggests']
# root: e, base: sugge, suggestion_list: ['suggests']
# root: s, base: sugges, suggestion_list: ['suggests']
# root: t, base: suggest, suggestion_list: ['suggests']
# root: s, base: suggests, suggestion_list: ['suggests']
# root: a, base: suga, suggestion_list: ['sugars']
# root: r, base: sugar, suggestion_list: ['sugars']
# root: s, base: sugars, suggestion_list: ['sugars']
# root: r, base: sur, suggestion_list: ['sure', 'survive']
# root: e, base: sure, suggestion_list: ['sure']
# root: v, base: surv, suggestion_list: ['survive']
# root: i, base: survi, suggestion_list: ['survive']
# root: v, base: surviv, suggestion_list: ['survive']
# root: e, base: survive, suggestion_list: ['survive']
# root: n, base: sun, suggestion_list: ['sun']
# root: o, base: so, suggestion_list: ['sound']
# root: u, base: sou, suggestion_list: ['sound']
# root: n, base: soun, suggestion_list: ['sound']
# root: d, base: sound, suggestion_list: ['sound']
# root: c, base: sc, suggestion_list: ['school']
# root: h, base: sch, suggestion_list: ['school']
# root: o, base: scho, suggestion_list: ['school']
# root: o, base: schoo, suggestion_list: ['school']
# root: l, base: school, suggestion_list: ['school']
# root: t, base: st, suggestion_list: ['start', 'styles', 'stomach', 'step']
# root: a, base: sta, suggestion_list: ['start']
# root: r, base: star, suggestion_list: ['start']
# root: t, base: start, suggestion_list: ['start']
# root: e, base: , suggestion_list: []
# root: d, base: , suggestion_list: []
# root: y, base: sty, suggestion_list: ['styles']
# root: l, base: styl, suggestion_list: ['styles']
# root: e, base: style, suggestion_list: ['styles']
# root: s, base: styles, suggestion_list: ['styles']
# root: o, base: sto, suggestion_list: ['stomach']
# root: m, base: stom, suggestion_list: ['stomach']
# root: a, base: stoma, suggestion_list: ['stomach']
# root: c, base: stomac, suggestion_list: ['stomach']
# root: h, base: stomach, suggestion_list: ['stomach']
# root: s, base: , suggestion_list: []
# root: e, base: ste, suggestion_list: ['step']
# root: p, base: step, suggestion_list: ['step']
# root: s, base: , suggestion_list: []
# root: w, base: sw, suggestion_list: ['sweet', 'swim']
# root: e, base: swe, suggestion_list: ['sweet']
# root: e, base: swee, suggestion_list: ['sweet']
# root: t, base: sweet, suggestion_list: ['sweet']
# root: i, base: swi, suggestion_list: ['swim']
# root: m, base: swim, suggestion_list: ['swim']
# root: y, base: sy, suggestion_list: ['systems']
# root: s, base: sys, suggestion_list: ['systems']
# root: t, base: syst, suggestion_list: ['systems']
# root: e, base: syste, suggestion_list: ['systems']
# root: m, base: system, suggestion_list: ['systems']
# root: s, base: systems, suggestion_list: ['systems']
# root: h, base: sh, suggestion_list: ['shell']
# root: e, base: she, suggestion_list: ['shell']
# root: l, base: shel, suggestion_list: ['shell']
# root: l, base: shell, suggestion_list: ['shell']
# root: b, base: b, suggestion_list: ['back', 'bach', 'bacteria', 'bar', 'bad', 'brain', 'brass', 'blindness', 'bird', 'bitter', 'big', 'beginning', 'become', 'better', 'beans', 'body', 'bunch']
# root: a, base: ba, suggestion_list: ['back', 'bach', 'bacteria', 'bar', 'bad']
# root: c, base: bac, suggestion_list: ['back', 'bach', 'bacteria']
# root: k, base: back, suggestion_list: ['back']
# root: h, base: bach, suggestion_list: ['bach']
# root: t, base: bact, suggestion_list: ['bacteria']
# root: e, base: bacte, suggestion_list: ['bacteria']
# root: r, base: bacter, suggestion_list: ['bacteria']
# root: i, base: bacteri, suggestion_list: ['bacteria']
# root: a, base: bacteria, suggestion_list: ['bacteria']
# root: r, base: bar, suggestion_list: ['bar']
# root: o, base: , suggestion_list: []
# root: q, base: , suggestion_list: []
# root: u, base: , suggestion_list: []
# root: e, base: , suggestion_list: []
# root: d, base: bad, suggestion_list: ['bad']
# root: r, base: br, suggestion_list: ['brain', 'brass']
# root: a, base: bra, suggestion_list: ['brain', 'brass']
# root: i, base: brai, suggestion_list: ['brain']
# root: n, base: brain, suggestion_list: ['brain']
# root: s, base: bras, suggestion_list: ['brass']
# root: s, base: brass, suggestion_list: ['brass']
# root: l, base: bl, suggestion_list: ['blindness']
# root: i, base: bli, suggestion_list: ['blindness']
# root: n, base: blin, suggestion_list: ['blindness']
# root: d, base: blind, suggestion_list: ['blindness']
# root: n, base: blindn, suggestion_list: ['blindness']
# root: e, base: blindne, suggestion_list: ['blindness']
# root: s, base: blindnes, suggestion_list: ['blindness']
# root: s, base: blindness, suggestion_list: ['blindness']
# root: i, base: bi, suggestion_list: ['bird', 'bitter', 'big']
# root: r, base: bir, suggestion_list: ['bird']
# root: d, base: bird, suggestion_list: ['bird']
# root: s, base: , suggestion_list: []
# root: t, base: bit, suggestion_list: ['bitter']
# root: t, base: bitt, suggestion_list: ['bitter']
# root: e, base: bitte, suggestion_list: ['bitter']
# root: r, base: bitter, suggestion_list: ['bitter']
# root: g, base: big, suggestion_list: ['big']
# root: e, base: be, suggestion_list: ['beginning', 'become', 'better', 'beans']
# root: g, base: beg, suggestion_list: ['beginning']
# root: i, base: begi, suggestion_list: ['beginning']
# root: n, base: begin, suggestion_list: ['beginning']
# root: n, base: beginn, suggestion_list: ['beginning']
# root: i, base: beginni, suggestion_list: ['beginning']
# root: n, base: beginnin, suggestion_list: ['beginning']
# root: g, base: beginning, suggestion_list: ['beginning']
# root: c, base: bec, suggestion_list: ['become']
# root: o, base: beco, suggestion_list: ['become']
# root: m, base: becom, suggestion_list: ['become']
# root: e, base: become, suggestion_list: ['become']
# root: t, base: bet, suggestion_list: ['better']
# root: t, base: bett, suggestion_list: ['better']
# root: e, base: bette, suggestion_list: ['better']
# root: r, base: better, suggestion_list: ['better']
# root: a, base: bea, suggestion_list: ['beans']
# root: n, base: bean, suggestion_list: ['beans']
# root: s, base: beans, suggestion_list: ['beans']
# root: o, base: bo, suggestion_list: ['body']
# root: d, base: bod, suggestion_list: ['body']
# root: y, base: body, suggestion_list: ['body']
# root: u, base: bu, suggestion_list: ['bunch']
# root: n, base: bun, suggestion_list: ['bunch']
# root: c, base: bunc, suggestion_list: ['bunch']
# root: h, base: bunch, suggestion_list: ['bunch']
# root: e, base: e, suggestion_list: ['eyes', 'example', 'exact', 'exhibiting', 'end', 'event', 'effect', 'equally', 'eat', 'eagle', 'ecological']
# root: y, base: ey, suggestion_list: ['eyes']
# root: e, base: eye, suggestion_list: ['eyes']
# root: s, base: eyes, suggestion_list: ['eyes']
# root: x, base: ex, suggestion_list: ['example', 'exact', 'exhibiting']
# root: a, base: exa, suggestion_list: ['example', 'exact']
# root: m, base: exam, suggestion_list: ['example']
# root: p, base: examp, suggestion_list: ['example']
# root: l, base: exampl, suggestion_list: ['example']
# root: e, base: example, suggestion_list: ['example']
# root: c, base: exac, suggestion_list: ['exact']
# root: t, base: exact, suggestion_list: ['exact']
# root: l, base: , suggestion_list: []
# root: y, base: , suggestion_list: []
# root: h, base: exh, suggestion_list: ['exhibiting']
# root: i, base: exhi, suggestion_list: ['exhibiting']
# root: b, base: exhib, suggestion_list: ['exhibiting']
# root: i, base: exhibi, suggestion_list: ['exhibiting']
# root: t, base: exhibit, suggestion_list: ['exhibiting']
# root: i, base: exhibiti, suggestion_list: ['exhibiting']
# root: n, base: exhibitin, suggestion_list: ['exhibiting']
# root: g, base: exhibiting, suggestion_list: ['exhibiting']
# root: n, base: en, suggestion_list: ['end']
# root: d, base: end, suggestion_list: ['end']
# root: v, base: ev, suggestion_list: ['event']
# root: e, base: eve, suggestion_list: ['event']
# root: n, base: even, suggestion_list: ['event']
# root: t, base: event, suggestion_list: ['event']
# root: f, base: ef, suggestion_list: ['effect']
# root: f, base: eff, suggestion_list: ['effect']
# root: e, base: effe, suggestion_list: ['effect']
# root: c, base: effec, suggestion_list: ['effect']
# root: t, base: effect, suggestion_list: ['effect']
# root: q, base: eq, suggestion_list: ['equally']
# root: u, base: equ, suggestion_list: ['equally']
# root: a, base: equa, suggestion_list: ['equally']
# root: l, base: equal, suggestion_list: ['equally']
# root: l, base: equall, suggestion_list: ['equally']
# root: y, base: equally, suggestion_list: ['equally']
# root: a, base: ea, suggestion_list: ['eat', 'eagle']
# root: t, base: eat, suggestion_list: ['eat']
# root: s, base: , suggestion_list: []
# root: g, base: eag, suggestion_list: ['eagle']
# root: l, base: eagl, suggestion_list: ['eagle']
# root: e, base: eagle, suggestion_list: ['eagle']
# root: c, base: ec, suggestion_list: ['ecological']
# root: o, base: eco, suggestion_list: ['ecological']
# root: l, base: ecol, suggestion_list: ['ecological']
# root: o, base: ecolo, suggestion_list: ['ecological']
# root: g, base: ecolog, suggestion_list: ['ecological']
# root: i, base: ecologi, suggestion_list: ['ecological']
# root: c, base: ecologic, suggestion_list: ['ecological']
# root: a, base: ecologica, suggestion_list: ['ecological']
# root: l, base: ecological, suggestion_list: ['ecological']
# root: t, base: t, suggestion_list: ['type', 'three', 'though', 'things', 'think', 'transverse', 'traditional', 'try', 'tree', 'taught', 'taste', 'tannin', 'time', 'technically', 'temperature', 'tempered', 'texture']
# root: y, base: ty, suggestion_list: ['type']
# root: p, base: typ, suggestion_list: ['type']
# root: e, base: type, suggestion_list: ['type']
# root: s, base: , suggestion_list: []
# root: h, base: th, suggestion_list: ['three', 'though', 'things', 'think']
# root: r, base: thr, suggestion_list: ['three']
# root: e, base: thre, suggestion_list: ['three']
# root: e, base: three, suggestion_list: ['three']
# root: o, base: tho, suggestion_list: ['though']
# root: u, base: thou, suggestion_list: ['though']
# root: g, base: thoug, suggestion_list: ['though']
# root: h, base: though, suggestion_list: ['though']
# root: t, base: , suggestion_list: []
# root: i, base: thi, suggestion_list: ['things', 'think']
# root: n, base: thin, suggestion_list: ['things', 'think']
# root: g, base: thing, suggestion_list: ['things']
# root: s, base: things, suggestion_list: ['things']
# root: k, base: think, suggestion_list: ['think']
# root: r, base: tr, suggestion_list: ['transverse', 'traditional', 'try', 'tree']
# root: a, base: tra, suggestion_list: ['transverse', 'traditional']
# root: n, base: tran, suggestion_list: ['transverse']
# root: s, base: trans, suggestion_list: ['transverse']
# root: v, base: transv, suggestion_list: ['transverse']
# root: e, base: transve, suggestion_list: ['transverse']
# root: r, base: transver, suggestion_list: ['transverse']
# root: s, base: transvers, suggestion_list: ['transverse']
# root: e, base: transverse, suggestion_list: ['transverse']
# root: d, base: trad, suggestion_list: ['traditional']
# root: i, base: tradi, suggestion_list: ['traditional']
# root: t, base: tradit, suggestion_list: ['traditional']
# root: i, base: traditi, suggestion_list: ['traditional']
# root: o, base: traditio, suggestion_list: ['traditional']
# root: n, base: tradition, suggestion_list: ['traditional']
# root: a, base: traditiona, suggestion_list: ['traditional']
# root: l, base: traditional, suggestion_list: ['traditional']
# root: y, base: try, suggestion_list: ['try']
# root: e, base: tre, suggestion_list: ['tree']
# root: e, base: tree, suggestion_list: ['tree']
# root: a, base: ta, suggestion_list: ['taught', 'taste', 'tannin']
# root: u, base: tau, suggestion_list: ['taught']
# root: g, base: taug, suggestion_list: ['taught']
# root: h, base: taugh, suggestion_list: ['taught']
# root: t, base: taught, suggestion_list: ['taught']
# root: s, base: tas, suggestion_list: ['taste']
# root: t, base: tast, suggestion_list: ['taste']
# root: e, base: taste, suggestion_list: ['taste']
# root: s, base: , suggestion_list: []
# root: n, base: tan, suggestion_list: ['tannin']
# root: n, base: tann, suggestion_list: ['tannin']
# root: i, base: tanni, suggestion_list: ['tannin']
# root: n, base: tannin, suggestion_list: ['tannin']
# root: s, base: , suggestion_list: []
# root: i, base: ti, suggestion_list: ['time']
# root: m, base: tim, suggestion_list: ['time']
# root: e, base: time, suggestion_list: ['time']
# root: e, base: te, suggestion_list: ['technically', 'temperature', 'tempered', 'texture']
# root: c, base: tec, suggestion_list: ['technically']
# root: h, base: tech, suggestion_list: ['technically']
# root: n, base: techn, suggestion_list: ['technically']
# root: i, base: techni, suggestion_list: ['technically']
# root: c, base: technic, suggestion_list: ['technically']
# root: a, base: technica, suggestion_list: ['technically']
# root: l, base: technical, suggestion_list: ['technically']
# root: l, base: technicall, suggestion_list: ['technically']
# root: y, base: technically, suggestion_list: ['technically']
# root: m, base: tem, suggestion_list: ['temperature', 'tempered']
# root: p, base: temp, suggestion_list: ['temperature', 'tempered']
# root: e, base: tempe, suggestion_list: ['temperature', 'tempered']
# root: r, base: temper, suggestion_list: ['temperature', 'tempered']
# root: a, base: tempera, suggestion_list: ['temperature']
# root: t, base: temperat, suggestion_list: ['temperature']
# root: u, base: temperatu, suggestion_list: ['temperature']
# root: r, base: temperatur, suggestion_list: ['temperature']
# root: e, base: temperature, suggestion_list: ['temperature']
# root: e, base: tempere, suggestion_list: ['tempered']
# ...
# root: l, base: fil, suggestion_list: ['filled']
# root: l, base: fill, suggestion_list: ['filled']
# root: e, base: fille, suggestion_list: ['filled']
# root: d, base: filled, suggestion_list: ['filled']
# root: n, base: fin, suggestion_list: ['finally']
# root: a, base: fina, suggestion_list: ['finally']
# root: l, base: final, suggestion_list: ['finally']
# root: l, base: finall, suggestion_list: ['finally']
# root: y, base: finally, suggestion_list: ['finally']
# root: o, base: fo, suggestion_list: ['four', 'foods', 'form']
# root: u, base: fou, suggestion_list: ['four']
# root: r, base: four, suggestion_list: ['four']
# root: o, base: foo, suggestion_list: ['foods']
# root: d, base: food, suggestion_list: ['foods']
# root: s, base: foods, suggestion_list: ['foods']
# root: r, base: for, suggestion_list: ['form']
# root: m, base: form, suggestion_list: ['form']
# root: l, base: fl, suggestion_list: ['flute', 'flavor', 'flightless']
# root: u, base: flu, suggestion_list: ['flute']
# root: t, base: flut, suggestion_list: ['flute']
# root: e, base: flute, suggestion_list: ['flute']
# root: s, base: , suggestion_list: []
# root: a, base: fla, suggestion_list: ['flavor']
# root: v, base: flav, suggestion_list: ['flavor']
# root: o, base: flavo, suggestion_list: ['flavor']
# root: r, base: flavor, suggestion_list: ['flavor']
# root: i, base: fli, suggestion_list: ['flightless']
# root: g, base: flig, suggestion_list: ['flightless']
# root: h, base: fligh, suggestion_list: ['flightless']
# root: t, base: flight, suggestion_list: ['flightless']
# root: l, base: flightl, suggestion_list: ['flightless']
# root: e, base: flightle, suggestion_list: ['flightless']
# root: s, base: flightles, suggestion_list: ['flightless']
# root: s, base: flightless, suggestion_list: ['flightless']
# root: e, base: fe, suggestion_list: ['features', 'feels', 'fermented']
# root: a, base: fea, suggestion_list: ['features']
# root: t, base: feat, suggestion_list: ['features']
# root: u, base: featu, suggestion_list: ['features']
# root: r, base: featur, suggestion_list: ['features']
# root: e, base: feature, suggestion_list: ['features']
# root: s, base: features, suggestion_list: ['features']
# root: e, base: fee, suggestion_list: ['feels']
# root: l, base: feel, suggestion_list: ['feels']
# root: s, base: feels, suggestion_list: ['feels']
# root: r, base: fer, suggestion_list: ['fermented']
# root: m, base: ferm, suggestion_list: ['fermented']
# root: e, base: ferme, suggestion_list: ['fermented']
# root: n, base: fermen, suggestion_list: ['fermented']
# root: t, base: ferment, suggestion_list: ['fermented']
# root: e, base: fermente, suggestion_list: ['fermented']
# root: d, base: fermented, suggestion_list: ['fermented']
# root: a, base: fa, suggestion_list: ['famous']
# root: m, base: fam, suggestion_list: ['famous']
# root: o, base: famo, suggestion_list: ['famous']
# root: u, base: famou, suggestion_list: ['famous']
# root: s, base: famous, suggestion_list: ['famous']
# root: n, base: n, suggestion_list: ['number', 'nutrition', 'name', 'new', 'need', 'niche', 'nibs']
# root: u, base: nu, suggestion_list: ['number', 'nutrition']
# root: m, base: num, suggestion_list: ['number']
# root: b, base: numb, suggestion_list: ['number']
# root: e, base: numbe, suggestion_list: ['number']
# root: r, base: number, suggestion_list: ['number']
# root: t, base: nut, suggestion_list: ['nutrition']
# root: r, base: nutr, suggestion_list: ['nutrition']
# root: i, base: nutri, suggestion_list: ['nutrition']
# root: t, base: nutrit, suggestion_list: ['nutrition']
# root: i, base: nutriti, suggestion_list: ['nutrition']
# root: o, base: nutritio, suggestion_list: ['nutrition']
# root: n, base: nutrition, suggestion_list: ['nutrition']
# root: a, base: na, suggestion_list: ['name']
# root: m, base: nam, suggestion_list: ['name']
# root: e, base: name, suggestion_list: ['name']
# root: e, base: ne, suggestion_list: ['new', 'need']
# root: w, base: new, suggestion_list: ['new']
# root: e, base: nee, suggestion_list: ['need']
# root: d, base: need, suggestion_list: ['need']
# root: s, base: , suggestion_list: []
# root: i, base: ni, suggestion_list: ['niche', 'nibs']
# root: c, base: nic, suggestion_list: ['niche']
# root: h, base: nich, suggestion_list: ['niche']
# root: e, base: niche, suggestion_list: ['niche']
# root: b, base: nib, suggestion_list: ['nibs']
# root: s, base: nibs, suggestion_list: ['nibs']
# root: v, base: v, suggestion_list: ['violet', 'vibrating', 'vitamins', 'virus', 'variety', 'variability']
# root: i, base: vi, suggestion_list: ['violet', 'vibrating', 'vitamins', 'virus']
# root: o, base: vio, suggestion_list: ['violet']
# root: l, base: viol, suggestion_list: ['violet']
# root: e, base: viole, suggestion_list: ['violet']
# root: t, base: violet, suggestion_list: ['violet']
# root: b, base: vib, suggestion_list: ['vibrating']
# root: r, base: vibr, suggestion_list: ['vibrating']
# root: a, base: vibra, suggestion_list: ['vibrating']
# root: t, base: vibrat, suggestion_list: ['vibrating']
# root: i, base: vibrati, suggestion_list: ['vibrating']
# root: n, base: vibratin, suggestion_list: ['vibrating']
# root: g, base: vibrating, suggestion_list: ['vibrating']
# root: t, base: vit, suggestion_list: ['vitamins']
# root: a, base: vita, suggestion_list: ['vitamins']
# root: m, base: vitam, suggestion_list: ['vitamins']
# root: i, base: vitami, suggestion_list: ['vitamins']
# root: n, base: vitamin, suggestion_list: ['vitamins']
# root: s, base: vitamins, suggestion_list: ['vitamins']
# root: r, base: vir, suggestion_list: ['virus']
# root: u, base: viru, suggestion_list: ['virus']
# root: s, base: virus, suggestion_list: ['virus']
# root: e, base: , suggestion_list: []
# root: s, base: , suggestion_list: []
# root: a, base: va, suggestion_list: ['variety', 'variability']
# root: r, base: var, suggestion_list: ['variety', 'variability']
# root: i, base: vari, suggestion_list: ['variety', 'variability']
# root: e, base: varie, suggestion_list: ['variety']
# root: t, base: variet, suggestion_list: ['variety']
# root: y, base: variety, suggestion_list: ['variety']
# root: a, base: varia, suggestion_list: ['variability']
# root: b, base: variab, suggestion_list: ['variability']
# root: i, base: variabi, suggestion_list: ['variability']
# root: l, base: variabil, suggestion_list: ['variability']
# root: i, base: variabili, suggestion_list: ['variability']
# root: t, base: variabilit, suggestion_list: ['variability']
# root: y, base: variability, suggestion_list: ['variability']
# root: g, base: g, suggestion_list: ['green', 'grew', 'gradually', 'grass', 'growing', 'growth', 'ground', 'giving', 'general', 'get', 'going', 'got']
# root: r, base: gr, suggestion_list: ['green', 'grew', 'gradually', 'grass', 'growing', 'growth', 'ground']
# root: e, base: gre, suggestion_list: ['green', 'grew']
# root: e, base: gree, suggestion_list: ['green']
# root: n, base: green, suggestion_list: ['green']
# root: w, base: grew, suggestion_list: ['grew']
# root: a, base: gra, suggestion_list: ['gradually', 'grass']
# root: d, base: grad, suggestion_list: ['gradually']
# root: u, base: gradu, suggestion_list: ['gradually']
# root: a, base: gradua, suggestion_list: ['gradually']
# root: l, base: gradual, suggestion_list: ['gradually']
# root: l, base: graduall, suggestion_list: ['gradually']
# root: y, base: gradually, suggestion_list: ['gradually']
# root: s, base: gras, suggestion_list: ['grass']
# root: s, base: grass, suggestion_list: ['grass']
# root: o, base: gro, suggestion_list: ['growing', 'growth', 'ground']
# root: w, base: grow, suggestion_list: ['growing', 'growth']
# root: i, base: growi, suggestion_list: ['growing']
# root: n, base: growin, suggestion_list: ['growing']
# root: g, base: growing, suggestion_list: ['growing']
# root: t, base: growt, suggestion_list: ['growth']
# root: h, base: growth, suggestion_list: ['growth']
# root: u, base: grou, suggestion_list: ['ground']
# root: n, base: groun, suggestion_list: ['ground']
# root: d, base: ground, suggestion_list: ['ground']
# root: i, base: gi, suggestion_list: ['giving']
# root: v, base: giv, suggestion_list: ['giving']
# root: i, base: givi, suggestion_list: ['giving']
# root: n, base: givin, suggestion_list: ['giving']
# root: g, base: giving, suggestion_list: ['giving']
# root: e, base: ge, suggestion_list: ['general', 'get']
# root: n, base: gen, suggestion_list: ['general']
# root: e, base: gene, suggestion_list: ['general']
# root: r, base: gener, suggestion_list: ['general']
# root: a, base: genera, suggestion_list: ['general']
# root: l, base: general, suggestion_list: ['general']
# root: l, base: , suggestion_list: []
# root: y, base: , suggestion_list: []
# root: t, base: get, suggestion_list: ['get']
# root: t, base: , suggestion_list: []
# root: i, base: , suggestion_list: []
# root: n, base: , suggestion_list: []
# root: g, base: , suggestion_list: []
# root: o, base: go, suggestion_list: ['going', 'got']
# root: i, base: goi, suggestion_list: ['going']
# root: n, base: goin, suggestion_list: ['going']
# root: g, base: going, suggestion_list: ['going']
# root: t, base: got, suggestion_list: ['got']
# root: y, base: y, suggestion_list: ['yellow']
# root: e, base: ye, suggestion_list: ['yellow']
# root: l, base: yel, suggestion_list: ['yellow']
# root: l, base: yell, suggestion_list: ['yellow']
# root: o, base: yello, suggestion_list: ['yellow']
# root: w, base: yellow, suggestion_list: ['yellow']
# root: u, base: u, suggestion_list: ['us', 'unlike']
# root: s, base: us, suggestion_list: ['us']
# root: u, base: , suggestion_list: []
# root: a, base: , suggestion_list: []
# root: l, base: , suggestion_list: []
# root: l, base: , suggestion_list: []
# root: y, base: , suggestion_list: []
# root: e, base: , suggestion_list: []
# root: n, base: un, suggestion_list: ['unlike']
# root: l, base: unl, suggestion_list: ['unlike']
# root: i, base: unli, suggestion_list: ['unlike']
# root: k, base: unlik, suggestion_list: ['unlike']
# root: e, base: unlike, suggestion_list: ['unlike']
# root: o, base: o, suggestion_list: ['one', 'oboes', 'opera', 'occurring', 'occupy', 'often', 'organisms']
# root: n, base: on, suggestion_list: ['one']
# root: e, base: one, suggestion_list: ['one']
# root: b, base: ob, suggestion_list: ['oboes']
# root: o, base: obo, suggestion_list: ['oboes']
# root: e, base: oboe, suggestion_list: ['oboes']
# root: s, base: oboes, suggestion_list: ['oboes']
# root: p, base: op, suggestion_list: ['opera']
# root: e, base: ope, suggestion_list: ['opera']
# root: r, base: oper, suggestion_list: ['opera']
# root: a, base: opera, suggestion_list: ['opera']
# root: c, base: oc, suggestion_list: ['occurring', 'occupy']
# root: c, base: occ, suggestion_list: ['occurring', 'occupy']
# root: u, base: occu, suggestion_list: ['occurring', 'occupy']
# root: r, base: occur, suggestion_list: ['occurring']
# root: r, base: occurr, suggestion_list: ['occurring']
# root: i, base: occurri, suggestion_list: ['occurring']
# root: n, base: occurrin, suggestion_list: ['occurring']
# root: g, base: occurring, suggestion_list: ['occurring']
# root: p, base: occup, suggestion_list: ['occupy']
# root: y, base: occupy, suggestion_list: ['occupy']
# root: f, base: of, suggestion_list: ['often']
# root: t, base: oft, suggestion_list: ['often']
# root: e, base: ofte, suggestion_list: ['often']
# root: n, base: often, suggestion_list: ['often']
# root: r, base: or, suggestion_list: ['organisms']
# root: g, base: org, suggestion_list: ['organisms']
# root: a, base: orga, suggestion_list: ['organisms']
# root: n, base: organ, suggestion_list: ['organisms']
# root: i, base: organi, suggestion_list: ['organisms']
# root: s, base: organis, suggestion_list: ['organisms']
# root: m, base: organism, suggestion_list: ['organisms']
# root: s, base: organisms, suggestion_list: ['organisms']
# root: m, base: m, suggestion_list: ['made', 'material', 'major', 'make', 'making', 'main', 'many', 'mammalian', 'mammals', 'metal', 'modify', 'mostly', 'mouth', 'moa', 'molded', 'musical', 'multiple']
# root: a, base: ma, suggestion_list: ['made', 'material', 'major', 'make', 'making', 'main', 'many', 'mammalian', 'mammals']
# root: d, base: mad, suggestion_list: ['made']
# root: e, base: made, suggestion_list: ['made']
# root: t, base: mat, suggestion_list: ['material']
# root: e, base: mate, suggestion_list: ['material']
# root: r, base: mater, suggestion_list: ['material']
# root: i, base: materi, suggestion_list: ['material']
# root: a, base: materia, suggestion_list: ['material']
# root: l, base: material, suggestion_list: ['material']
# root: j, base: maj, suggestion_list: ['major']
# root: o, base: majo, suggestion_list: ['major']
# root: r, base: major, suggestion_list: ['major']
# root: k, base: mak, suggestion_list: ['make', 'making']
# root: e, base: make, suggestion_list: ['make']
# root: i, base: maki, suggestion_list: ['making']
# root: n, base: makin, suggestion_list: ['making']
# root: g, base: making, suggestion_list: ['making']
# root: i, base: mai, suggestion_list: ['main']
# root: n, base: main, suggestion_list: ['main']
# root: n, base: man, suggestion_list: ['many']
# root: y, base: many, suggestion_list: ['many']
# root: m, base: mam, suggestion_list: ['mammalian', 'mammals']
# root: m, base: mamm, suggestion_list: ['mammalian', 'mammals']
# root: a, base: mamma, suggestion_list: ['mammalian', 'mammals']
# root: l, base: mammal, suggestion_list: ['mammalian', 'mammals']
# root: i, base: mammali, suggestion_list: ['mammalian']
# root: a, base: mammalia, suggestion_list: ['mammalian']
# root: n, base: mammalian, suggestion_list: ['mammalian']
# root: s, base: mammals, suggestion_list: ['mammals']
# root: e, base: me, suggestion_list: ['metal']
# root: t, base: met, suggestion_list: ['metal']
# root: a, base: meta, suggestion_list: ['metal']
# root: l, base: metal, suggestion_list: ['metal']
# root: o, base: mo, suggestion_list: ['modify', 'mostly', 'mouth', 'moa', 'molded']
# root: d, base: mod, suggestion_list: ['modify']
# root: i, base: modi, suggestion_list: ['modify']
# root: f, base: modif, suggestion_list: ['modify']
# root: y, base: modify, suggestion_list: ['modify']
# root: s, base: mos, suggestion_list: ['mostly']
# root: t, base: most, suggestion_list: ['mostly']
# root: l, base: mostl, suggestion_list: ['mostly']
# root: y, base: mostly, suggestion_list: ['mostly']
# root: u, base: mou, suggestion_list: ['mouth']
# root: t, base: mout, suggestion_list: ['mouth']
# root: h, base: mouth, suggestion_list: ['mouth']
# root: a, base: moa, suggestion_list: ['moa']
# root: l, base: mol, suggestion_list: ['molded']
# root: d, base: mold, suggestion_list: ['molded']
# root: e, base: molde, suggestion_list: ['molded']
# root: d, base: molded, suggestion_list: ['molded']
# root: u, base: mu, suggestion_list: ['musical', 'multiple']
# root: s, base: mus, suggestion_list: ['musical']
# root: i, base: musi, suggestion_list: ['musical']
# root: c, base: music, suggestion_list: ['musical']
# root: a, base: musica, suggestion_list: ['musical']
# root: l, base: musical, suggestion_list: ['musical']
# root: l, base: mul, suggestion_list: ['multiple']
# root: t, base: mult, suggestion_list: ['multiple']
# root: i, base: multi, suggestion_list: ['multiple']
# root: p, base: multip, suggestion_list: ['multiple']
# root: l, base: multipl, suggestion_list: ['multiple']
# root: e, base: multiple, suggestion_list: ['multiple']
# root: j, base: j, suggestion_list: ['johann']
# root: o, base: jo, suggestion_list: ['johann']
# root: h, base: joh, suggestion_list: ['johann']
# root: a, base: joha, suggestion_list: ['johann']
# root: n, base: johan, suggestion_list: ['johann']
# root: n, base: johann, suggestion_list: ['johann']
# root: k, base: k, suggestion_list: ['known', 'kind']
# root: n, base: kn, suggestion_list: ['known']
# root: o, base: kno, suggestion_list: ['known']
# root: w, base: know, suggestion_list: ['known']
# root: n, base: known, suggestion_list: ['known']
# root: i, base: ki, suggestion_list: ['kind']
# root: n, base: kin, suggestion_list: ['kind']
# root: d, base: kind, suggestion_list: ['kind']
# root: z, base: z, suggestion_list: ['zealand']
# root: e, base: ze, suggestion_list: ['zealand']
# root: a, base: zea, suggestion_list: ['zealand']
# root: l, base: zeal, suggestion_list: ['zealand']
# root: a, base: zeala, suggestion_list: ['zealand']
# root: n, base: zealan, suggestion_list: ['zealand']
# root: d, base: zealand, suggestion_list: ['zealand']

# %%
# DFS on tries to get the words

q = [trie_root_node_test.root]
# v = [trie_root_node]
curr_word = ''

while q:
    root = q.pop()
    print(root.val)
    curr_word += root.val
    if root.end:
#         root.suggestion_list.append(curr_word)
        print(curr_word)
#         curr_word = curr_word[:-1]
    for val, node in root.children.items():
        q.append(node)
# Out:
# c
# o
# m
# m
# o
# n
# common
# l
# d
# commonld
# a
# s
# t
# commonldast
# r
# commonldastr
# m
# e
# r
# o
# n
# commonldastrmeron
# l
# commonldastrmeronl

# %%
# All keywords formed in a trie
trie_root_node_test = Trie()

test_words = ['camel', 'car', 'cast', 'cameron', 'cold', 'common']

for word in test_words:
    trie_root_node_test.insert(word)
    
prefix_hash_table = {}

# Organising the Tries
def dfs(root, curr_word=''):
    root.base = curr_word
    prefix_hash_table[root.base] = root.suggestion_list
    if root.end: 
        root.suggestion_list.append(curr_word)
        return [curr_word]
    
    for val, node in root.children.items():
        to_return = dfs(node, curr_word+node.val)
        root.suggestion_list += to_return
    
    return root.suggestion_list
        
dfs(trie_root_node_test.root)

# Remove the null entry
prefix_hash_table.pop('', None)
# Out:
# ['camel', 'cameron', 'car', 'cast', 'cold', 'common']

# %%
# View All suggestion list
def dfs(root, curr_word=''):
    print(f'root: {root.val}, base: {root.base}, suggestion_list: {root.suggestion_list}')
    for val, node in root.children.items():
        dfs(node, curr_word)
        
dfs(trie_root_node_test.root)
# Out:
# root: , base: , suggestion_list: ['camel', 'cameron', 'car', 'cast', 'cold', 'common']
# root: c, base: c, suggestion_list: ['camel', 'cameron', 'car', 'cast', 'cold', 'common']
# root: a, base: ca, suggestion_list: ['camel', 'cameron', 'car', 'cast']
# root: m, base: cam, suggestion_list: ['camel', 'cameron']
# root: e, base: came, suggestion_list: ['camel', 'cameron']
# root: l, base: camel, suggestion_list: ['camel']
# root: r, base: camer, suggestion_list: ['cameron']
# root: o, base: camero, suggestion_list: ['cameron']
# root: n, base: cameron, suggestion_list: ['cameron']
# root: r, base: car, suggestion_list: ['car']
# root: s, base: cas, suggestion_list: ['cast']
# root: t, base: cast, suggestion_list: ['cast']
# root: o, base: co, suggestion_list: ['cold', 'common']
# root: l, base: col, suggestion_list: ['cold']
# root: d, base: cold, suggestion_list: ['cold']
# root: m, base: com, suggestion_list: ['common']
# root: m, base: comm, suggestion_list: ['common']
# root: o, base: commo, suggestion_list: ['common']
# root: n, base: common, suggestion_list: ['common']

# %%
inverted_json
# Out:
# {'different': {'freq': 9, 'doc': [0, 4, 5]},
#  'animals': {'freq': 4, 'doc': [0, 8, 6]},
#  'perceive': {'freq': 3, 'doc': [0]},
#  'colors': {'freq': 3, 'doc': [0]},
#  'larger': {'freq': 3, 'doc': [0, 6]},
#  'including': {'freq': 1, 'doc': [0]},
#  'humans': {'freq': 5, 'doc': [0, 8, 7]},
#  'special': {'freq': 4, 'doc': [0, 8]},
#  'cells': {'freq': 3, 'doc': [0, 8]},
#  'back': {'freq': 1, 'doc': [0]},
#  'eyes': {'freq': 1, 'doc': [0]},
#  'called': {'freq': 3, 'doc': [0, 1, 4]},
#  'cone': {'freq': 4, 'doc': [0]},
#  'type': {'freq': 1, 'doc': [0]},
#  'cell': {'freq': 5, 'doc': [0, 7]},
#  'reacts': {'freq': 1, 'doc': [0]},
#  'specific': {'freq': 3, 'doc': [0, 4]},
#  'wavelength': {'freq': 3, 'doc': [0]},
#  'light': {'freq': 2, 'doc': [0]},
#  'whose': {'freq': 1, 'doc': [0]},
#  'color': {'freq': 4, 'doc': [0, 4]},
#  'corresponds': {'freq': 1, 'doc': [0]},
#  'part': {'freq': 2, 'doc': [0, 6]},
#  'rainbow': {'freq': 1, 'doc': [0]},
#  'hit': {'freq': 1, 'doc': [0]},
#  'right': {'freq': 2, 'doc': [0, 9]},
#  'sends': {'freq': 1, 'doc': [0]},
#  'signal': {'freq': 1, 'doc': [0]},
#  'brain': {'freq': 1, 'doc': [0]},
#  'combines': {'freq': 1, 'doc': [0]},
#  'information': {'freq': 1, 'doc': [0]},
#  'types': {'freq': 5, 'doc': [0]},
#  'full': {'freq': 1, 'doc': [0]},
#  'range': {'freq': 1, 'doc': [0]},
#  'animal': {'freq': 2, 'doc': [0, 8]},
#  'sees': {'freq': 1, 'doc': [0]},
#  'depends': {'freq': 1, 'doc': [0]},
#  'number': {'freq': 1, 'doc': [0]},
#  'react': {'freq': 1, 'doc': [0]},
#  'example': {'freq': 6, 'doc': [0, 9, 2, 6]},
#  'three': {'freq': 1, 'doc': [0]},
#  'violet': {'freq': 1, 'doc': [0]},
#  'green': {'freq': 2, 'doc': [0]},
#  'yellow': {'freq': 1, 'doc': [0]},
#  'us': {'freq': 1, 'doc': [0]},
#  'lack': {'freq': 1, 'doc': [0]},
#  'one': {'freq': 1, 'doc': [0]},
#  'leading': {'freq': 1, 'doc': [0]},
#  'red': {'freq': 1, 'doc': [0]},
#  'blindness': {'freq': 1, 'doc': [0]},
#  'species': {'freq': 2, 'doc': [0, 6]},
#  'bird': {'freq': 2, 'doc': [0, 6]},
#  'fish': {'freq': 1, 'doc': [0]},
#  'hand': {'freq': 2, 'doc': [0, 3]},
#  'four': {'freq': 1, 'doc': [0]},
#  'giving': {'freq': 1, 'doc': [0]},
#  'perception': {'freq': 1, 'doc': [0]},
#  'flutes': {'freq': 1, 'doc': [1]},
#  'classified': {'freq': 1, 'doc': [1]},
#  'woodwinds': {'freq': 4, 'doc': [1]},
#  'made': {'freq': 2, 'doc': [1]},
#  'metal': {'freq': 1, 'doc': [1]},
#  'contrary': {'freq': 1, 'doc': [1]},
#  'name': {'freq': 1, 'doc': [1]},
#  'suggests': {'freq': 1, 'doc': [1]},
#  'difference': {'freq': 2, 'doc': [1, 7]},
#  'brass': {'freq': 2, 'doc': [1]},
#  'instruments': {'freq': 2, 'doc': [1]},
#  'sound': {'freq': 3, 'doc': [1]},
#  'produced': {'freq': 2, 'doc': [1]},
#  'rather': {'freq': 1, 'doc': [1]},
#  'material': {'freq': 1, 'doc': [1]},
#  'large': {'freq': 3, 'doc': [1, 6]},
#  'amplify': {'freq': 1, 'doc': [1]},
#  'modify': {'freq': 1, 'doc': [1]},
#  'lips': {'freq': 1, 'doc': [1]},
#  'vibrating': {'freq': 3, 'doc': [1]},
#  'create': {'freq': 1, 'doc': [1]},
#  'wind': {'freq': 1, 'doc': [1]},
#  'directed': {'freq': 1, 'doc': [1]},
#  'happen': {'freq': 2, 'doc': [1, 2]},
#  'reed': {'freq': 1, 'doc': [1]},
#  'case': {'freq': 1, 'doc': [1]},
#  'oboes': {'freq': 1, 'doc': [1]},
#  'clarinets': {'freq': 1, 'doc': [1]},
#  'air': {'freq': 1, 'doc': [1]},
#  'column': {'freq': 1, 'doc': [1]},
#  'contained': {'freq': 1, 'doc': [1]},
#  'within': {'freq': 2, 'doc': [1, 4]},
#  'transverse': {'freq': 1, 'doc': [1]},
#  'flute': {'freq': 1, 'doc': [1]},
#  'recorder': {'freq': 1, 'doc': [1]},
#  'set': {'freq': 1, 'doc': [2]},
#  'date': {'freq': 2, 'doc': [2]},
#  'beginning': {'freq': 2, 'doc': [2]},
#  'end': {'freq': 3, 'doc': [2]},
#  'artistic': {'freq': 2, 'doc': [2]},
#  'period': {'freq': 5, 'doc': [2]},
#  'change': {'freq': 1, 'doc': [2]},
#  'gradually': {'freq': 1, 'doc': [2]},
#  'exact': {'freq': 1, 'doc': [2]},
#  'periods': {'freq': 1, 'doc': [2]},
#  'taught': {'freq': 1, 'doc': [2]},
#  'school': {'freq': 1, 'doc': [2]},
#  'mostly': {'freq': 2, 'doc': [2]},
#  'arbitrary': {'freq': 1, 'doc': [2]},
#  'art': {'freq': 2, 'doc': [2]},
#  'historians': {'freq': 1, 'doc': [2]},
#  'usually': {'freq': 1, 'doc': [2]},
#  'try': {'freq': 2, 'doc': [2, 6]},
#  'use': {'freq': 1, 'doc': [2]},
#  'major': {'freq': 1, 'doc': [2]},
#  'event': {'freq': 1, 'doc': [2]},
#  'creation': {'freq': 1, 'doc': [2]},
#  'piece': {'freq': 1, 'doc': [2]},
#  'features': {'freq': 2, 'doc': [2]},
#  'characteristics': {'freq': 1, 'doc': [2]},
#  'new': {'freq': 3, 'doc': [2, 6]},
#  'death': {'freq': 2, 'doc': [2]},
#  'representative': {'freq': 1, 'doc': [2]},
#  'character': {'freq': 1, 'doc': [2]},
#  'baroque': {'freq': 2, 'doc': [2]},
#  'widely': {'freq': 1, 'doc': [2]},
#  'thought': {'freq': 1, 'doc': [2]},
#  'start': {'freq': 1, 'doc': [2]},
#  'first': {'freq': 2, 'doc': [2]},
#  'representation': {'freq': 1, 'doc': [2]},
#  'opera': {'freq': 1, 'doc': [2]},
#  'famous': {'freq': 1, 'doc': [2]},
#  'composer': {'freq': 1, 'doc': [2]},
#  'johann': {'freq': 1, 'doc': [2]},
#  'sebastian': {'freq': 1, 'doc': [2]},
#  'bach': {'freq': 2, 'doc': [2]},
#  'however': {'freq': 2, 'doc': [8, 2]},
#  'musical': {'freq': 1, 'doc': [2]},
#  'styles': {'freq': 1, 'doc': [2]},
#  'actually': {'freq': 2, 'doc': [2, 6]},
#  'started': {'freq': 1, 'doc': [2]},
#  'changing': {'freq': 1, 'doc': [2]},
#  'long': {'freq': 1, 'doc': [2]},
#  'passed': {'freq': 1, 'doc': [2]},
#  'away': {'freq': 1, 'doc': [2]},
#  'already': {'freq': 1, 'doc': [2]},
#  'exhibiting': {'freq': 1, 'doc': [2]},
#  'become': {'freq': 1, 'doc': [2]},
#  'known': {'freq': 1, 'doc': [2]},
#  'classical': {'freq': 1, 'doc': [2]},
#  'general': {'freq': 1, 'doc': [2]},
#  'dates': {'freq': 1, 'doc': [2]},
#  'way': {'freq': 1, 'doc': [2]},
#  'remember': {'freq': 1, 'doc': [2]},
#  'came': {'freq': 1, 'doc': [2]},
#  'decades': {'freq': 1, 'doc': [2]},
#  'cover': {'freq': 1, 'doc': [2]},
#  'adults': {'freq': 1, 'doc': [3]},
#  'like': {'freq': 7, 'doc': [8, 3, 4, 5]},
#  'drinking': {'freq': 1, 'doc': [3]},
#  'coffee': {'freq': 2, 'doc': [3]},
#  'tastes': {'freq': 2, 'doc': [3, 4]},
#  'bad': {'freq': 1, 'doc': [3]},
#  'children': {'freq': 1, 'doc': [3]},
#  'generally': {'freq': 2, 'doc': [3]},
#  'sweet': {'freq': 1, 'doc': [3]},
#  'things': {'freq': 1, 'doc': [3]},
#  'probably': {'freq': 1, 'doc': [3]},
#  'growing': {'freq': 1, 'doc': [3]},
#  'sugars': {'freq': 1, 'doc': [3]},
#  'help': {'freq': 2, 'doc': [8, 3]},
#  'growth': {'freq': 1, 'doc': [3]},
#  'bitter': {'freq': 1, 'doc': [3]},
#  'acquired': {'freq': 1, 'doc': [3]},
#  'taste': {'freq': 5, 'doc': [3, 4]},
#  'happens': {'freq': 1, 'doc': [4]},
#  'wine': {'freq': 8, 'doc': [4]},
#  'ages': {'freq': 2, 'doc': [4]},
#  'make': {'freq': 4, 'doc': [9, 4]},
#  'better': {'freq': 4, 'doc': [4]},
#  'chemical': {'freq': 2, 'doc': [4]},
#  'reaction': {'freq': 2, 'doc': [4]},
#  'occurring': {'freq': 1, 'doc': [4]},
#  'changes': {'freq': 1, 'doc': [4]},
#  'flavor': {'freq': 2, 'doc': [9, 4]},
#  'also': {'freq': 2, 'doc': [4, 6]},
#  'affect': {'freq': 2, 'doc': [9, 4]},
#  'feels': {'freq': 1, 'doc': [4]},
#  'inside': {'freq': 2, 'doc': [9, 4]},
#  'mouth': {'freq': 1, 'doc': [4]},
#  'age': {'freq': 1, 'doc': [4]},
#  'though': {'freq': 1, 'doc': [4]},
#  'compound': {'freq': 1, 'doc': [4]},
#  'tannin': {'freq': 1, 'doc': [4]},
#  'big': {'freq': 1, 'doc': [4]},
#  'effect': {'freq': 1, 'doc': [4]},
#  'going': {'freq': 1, 'doc': [4]},
#  'aging': {'freq': 2, 'doc': [4]},
#  'wines': {'freq': 1, 'doc': [4]},
#  'amounts': {'freq': 1, 'doc': [4]},
#  'tannins': {'freq': 1, 'doc': [4]},
#  'equally': {'freq': 1, 'doc': [4]},
#  'exactly': {'freq': 1, 'doc': [5]},
#  'vitamins': {'freq': 3, 'doc': [5]},
#  'kind': {'freq': 1, 'doc': [5]},
#  'nutrition': {'freq': 2, 'doc': [8, 5]},
#  'body': {'freq': 1, 'doc': [5]},
#  'needs': {'freq': 3, 'doc': [8, 5, 7]},
#  'work': {'freq': 1, 'doc': [5]},
#  'properly': {'freq': 1, 'doc': [5]},
#  'need': {'freq': 2, 'doc': [5]},
#  'eat': {'freq': 2, 'doc': [8, 5]},
#  'variety': {'freq': 1, 'doc': [5]},
#  'foods': {'freq': 1, 'doc': [5]},
#  'bunch': {'freq': 1, 'doc': [5]},
#  'main': {'freq': 1, 'doc': [6]},
#  'predators': {'freq': 3, 'doc': [6]},
#  'zealand': {'freq': 2, 'doc': [6]},
#  'birds': {'freq': 6, 'doc': [6]},
#  'compared': {'freq': 1, 'doc': [6]},
#  'places': {'freq': 1, 'doc': [6]},
#  'world': {'freq': 1, 'doc': [6]},
#  'sure': {'freq': 1, 'doc': [6]},
#  'since': {'freq': 1, 'doc': [6]},
#  'island': {'freq': 2, 'doc': [6]},
#  'possible': {'freq': 1, 'doc': [6]},
#  'many': {'freq': 2, 'doc': [9, 6]},
#  'mammalian': {'freq': 1, 'doc': [6]},
#  'could': {'freq': 1, 'doc': [6]},
#  'access': {'freq': 2, 'doc': [8, 6]},
#  'mammals': {'freq': 2, 'doc': [6]},
#  'swim': {'freq': 1, 'doc': [6]},
#  'present': {'freq': 1, 'doc': [6]},
#  'seals': {'freq': 1, 'doc': [6]},
#  'whales': {'freq': 1, 'doc': [6]},
#  'time': {'freq': 3, 'doc': [9, 6]},
#  'ecological': {'freq': 1, 'doc': [6]},
#  'niche': {'freq': 1, 'doc': [6]},
#  'often': {'freq': 2, 'doc': [6]},
#  'occupy': {'freq': 1, 'doc': [6]},
#  'filled': {'freq': 1, 'doc': [6]},
#  'without': {'freq': 1, 'doc': [6]},
#  'traditional': {'freq': 1, 'doc': [6]},
#  'preyed': {'freq': 1, 'doc': [6]},
#  'population': {'freq': 1, 'doc': [6]},
#  'grew': {'freq': 1, 'doc': [6]},
#  'lot': {'freq': 4, 'doc': [8, 9, 6, 7]},
#  'flightless': {'freq': 1, 'doc': [6]},
#  'think': {'freq': 1, 'doc': [6]},
#  'prey': {'freq': 1, 'doc': [6]},
#  'getting': {'freq': 1, 'doc': [6]},
#  'moa': {'freq': 1, 'doc': [6]},
#  'ate': {'freq': 1, 'doc': [6]},
#  'got': {'freq': 1, 'doc': [6]},
#  'haast': {'freq': 1, 'doc': [6]},
#  'eagle': {'freq': 1, 'doc': [6]},
#  'viruses': {'freq': 2, 'doc': [7]},
#  'bacteria': {'freq': 4, 'doc': [7]},
#  'virus': {'freq': 1, 'doc': [7]},
#  'technically': {'freq': 1, 'doc': [7]},
#  'alive': {'freq': 1, 'doc': [7]},
#  'attach': {'freq': 1, 'doc': [7]},
#  'living': {'freq': 2, 'doc': [7]},
#  'host': {'freq': 1, 'doc': [7]},
#  'able': {'freq': 1, 'doc': [7]},
#  'reproduce': {'freq': 1, 'doc': [7]},
#  'organisms': {'freq': 1, 'doc': [7]},
#  'cause': {'freq': 1, 'doc': [7]},
#  'disease': {'freq': 1, 'doc': [7]},
#  'helpful': {'freq': 1, 'doc': [7]},
#  'well': {'freq': 1, 'doc': [7]},
#  'herbivore': {'freq': 1, 'doc': [8]},
#  'eats': {'freq': 2, 'doc': [8]},
#  'plants': {'freq': 4, 'doc': [8]},
#  'get': {'freq': 2, 'doc': [8]},
#  'protein': {'freq': 3, 'doc': [8]},
#  'survive': {'freq': 1, 'doc': [8]},
#  'grass': {'freq': 2, 'doc': [8]},
#  'herbivores': {'freq': 2, 'doc': [8]},
#  'unlike': {'freq': 1, 'doc': [8]},
#  'digestive': {'freq': 2, 'doc': [8]},
#  'systems': {'freq': 2, 'doc': [8]},
#  'let': {'freq': 1, 'doc': [8]},
#  'contain': {'freq': 1, 'doc': [8]},
#  'cellulose': {'freq': 3, 'doc': [8]},
#  'difficult': {'freq': 1, 'doc': [8]},
#  'digest': {'freq': 1, 'doc': [8]},
#  'cows': {'freq': 2, 'doc': [8]},
#  'process': {'freq': 1, 'doc': [8]},
#  'protected': {'freq': 1, 'doc': [8]},
#  'plant': {'freq': 1, 'doc': [8]},
#  'multiple': {'freq': 1, 'doc': [8]},
#  'stomachs': {'freq': 1, 'doc': [8]},
#  'areas': {'freq': 1, 'doc': [8]},
#  'stomach': {'freq': 1, 'doc': [8]},
#  'intestine': {'freq': 1, 'doc': [8]},
#  'digesting': {'freq': 1, 'doc': [8]},
#  'chocolate': {'freq': 5, 'doc': [9]},
#  'steps': {'freq': 1, 'doc': [9]},
#  'making': {'freq': 1, 'doc': [9]},
#  'cocoa': {'freq': 4, 'doc': [9]},
#  'tree': {'freq': 1, 'doc': [9]},
#  'harvested': {'freq': 1, 'doc': [9]},
#  'produce': {'freq': 1, 'doc': [9]},
#  'pods': {'freq': 2, 'doc': [9]},
#  'pulp': {'freq': 1, 'doc': [9]},
#  'fermented': {'freq': 1, 'doc': [9]},
#  'beans': {'freq': 3, 'doc': [9]},
#  'dried': {'freq': 1, 'doc': [9]},
#  'sun': {'freq': 1, 'doc': [9]},
#  'roasted': {'freq': 2, 'doc': [9]},
#  'step': {'freq': 1, 'doc': [9]},
#  'variability': {'freq': 1, 'doc': [9]},
#  'temperature': {'freq': 1, 'doc': [9]},
#  'roast': {'freq': 1, 'doc': [9]},
#  'processed': {'freq': 1, 'doc': [9]},
#  'remove': {'freq': 1, 'doc': [9]},
#  'shell': {'freq': 1, 'doc': [9]},
#  'nibs': {'freq': 1, 'doc': [9]},
#  'ground': {'freq': 1, 'doc': [9]},
#  'tempered': {'freq': 1, 'doc': [9]},
#  'form': {'freq': 1, 'doc': [9]},
#  'texture': {'freq': 1, 'doc': [9]},
#  'finally': {'freq': 1, 'doc': [9]},
#  'molded': {'freq': 1, 'doc': [9]},
#  'bar': {'freq': 1, 'doc': [9]}}

# %%
prefix_hash_table
# Out:
# {'c': ['camel', 'cameron', 'car', 'cast', 'cold', 'common'],
#  'ca': ['camel', 'cameron', 'car', 'cast'],
#  'cam': ['camel', 'cameron'],
#  'came': ['camel', 'cameron'],
#  'camel': ['camel'],
#  'camer': ['cameron'],
#  'camero': ['cameron'],
#  'cameron': ['cameron'],
#  'car': ['car'],
#  'cas': ['cast'],
#  'cast': ['cast'],
#  'co': ['cold', 'common'],
#  'col': ['cold'],
#  'cold': ['cold'],
#  'com': ['common'],
#  'comm': ['common'],
#  'commo': ['common'],
#  'common': ['common']}

# %%
with open('sample_indexing.js', 'w') as w:
    w.write('data = ')
    json.dump(prefix_hash_table, w)

# %%
with open('inverted_indexing.js', 'w') as w:
    w.write('invertedIndex = ')
    json.dump(inverted_json, w)

# %%
with open('documents.js', 'w') as w:
    w.write('docIndex = ')
    json.dump(data, w)
